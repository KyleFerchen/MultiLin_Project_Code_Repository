# %%
import os
import pandas as pd
import numpy as np
import anndata
from pyInfinityFlow.InfinityFlow_Utilities import read_fcs_into_anndata
from pyInfinityFlow.fcs_io import FCSFileObject

os.chdir("/media/kyle_storage/kyle_ferchen/grimes_lab_main/analysis/"\
    "2022_12_07_new_multilin_panel/")

# %%
# Read in the InfinityFlow fcs file
tmp_fcs = read_fcs_into_anndata("output/infinity_flow/infinity_flow_reprediction_on_new_panal_logicle_redo.fcs")
tmp_fcs
# Out:
# AnnData object with n_obs × n_vars = 1935037 × 149
#     obs: 'cell_number'
#     var: 'name', 'USE_LOGICLE', 'LOGICLE_T', 'LOGICLE_W', 'LOGICLE_M', 'LOGICLE_A', 'LOGICLE_APPLIED', 'IMPUTED'

# %%
print(tmp_fcs.var.to_string())
# Out:
#                                             name  USE_LOGICLE  LOGICLE_T  LOGICLE_W  LOGICLE_M  LOGICLE_A  LOGICLE_APPLIED  IMPUTED
# APC-A                                      CD371         True  3000000.0        0.0        3.0        1.0            False    False
# APC-Cy7-A                                   CD48         True  3000000.0        0.0        3.0        1.0            False    False
# AlexaFluor647-A                             CD55         True  3000000.0        0.0        3.0        1.0            False    False
# AlexaFluor700-A                             Ly6G         True  3000000.0        0.0        3.0        1.0            False    False
# BUV395-A                                 CD16_32         True  3000000.0        0.0        3.0        1.0            False    False
# BUV615-A                                   ITGB7         True  3000000.0        0.0        3.0        1.0            False    False
# BUV737-A                                    CD27         True  3000000.0        0.0        3.0        1.0            False    False
# BUV805-A                                   CD105         True  3000000.0        0.0        3.0        1.0            False    False
# BV421-A                                    CD131         True  3000000.0        0.0        3.0        1.0            False    False
# BV480-A                                     CD93         True  3000000.0        0.0        3.0        1.0            False    False
# BV510-A                                Lin_Strep         True  3000000.0        0.0        3.0        1.0            False    False
# BV570-A                                     Ly6C         True  3000000.0        0.0        3.0        1.0            False    False
# BV605-A                                     CD41         True  3000000.0        0.0        3.0        1.0            False    False
# BV650-A                                    CD117         True  3000000.0        0.0        3.0        1.0            False    False
# BV711-A                                    CD150         True  3000000.0        0.0        3.0        1.0            False    False
# BV750-A                                    CD11b         True  3000000.0        0.0        3.0        1.0            False    False
# BV785-A                                    CD127         True  3000000.0        0.0        3.0        1.0            False    False
# GFP-A                                       Irf8         True  3000000.0        0.0        3.0        1.0            False    False
# PE-A                                      CX3CR1         True  3000000.0        0.0        3.0        1.0            False    False
# PE-Cy5-A                                   CD135         True  3000000.0        0.0        3.0        1.0            False    False
# PE-Cy5.5-A                                   Sca         True  3000000.0        0.0        3.0        1.0            False    False
# PE-Cy7-A                                   CD125         True  3000000.0        0.0        3.0        1.0            False    False
# PacificBlue-A                             FCER1A         True  3000000.0        0.0        3.0        1.0            False    False
# PerCP-Cy5.5-A                              CD106         True  3000000.0        0.0        3.0        1.0            False    False
# PerCP-eFluor710-A                          CD201         True  3000000.0        0.0        3.0        1.0            False    False
# leiden                                                   True  3000000.0        0.0        3.0        1.0            False    False
# Time                                                    False  3000000.0        0.0        3.0        1.0            False    False
# SSC-W                                                   False  3000000.0        0.0        3.0        1.0            False    False
# SSC-H                                                   False  3000000.0        0.0        3.0        1.0            False    False
# SSC-A                                                   False  3000000.0        0.0        3.0        1.0            False    False
# FSC-W                                                   False  3000000.0        0.0        3.0        1.0            False    False
# FSC-H                                                   False  3000000.0        0.0        3.0        1.0            False    False
# FSC-A                                                   False  3000000.0        0.0        3.0        1.0            False    False
# SSC-B-W                                                 False  3000000.0        0.0        3.0        1.0            False    False
# SSC-B-H                                                 False  3000000.0        0.0        3.0        1.0            False    False
# SSC-B-A                                                 False  3000000.0        0.0        3.0        1.0            False    False
# LIVEDEADBlue-A                              DEAD         True  3000000.0        0.0        3.0        1.0            False    False
# AF-A                                                     True  3000000.0        0.0        3.0        1.0            False    False
# umap-x                                                  False  3000000.0        0.0        3.0        1.0            False    False
# umap-y                                                  False  3000000.0        0.0        3.0        1.0            False    False
# Bhlhe40-GFP                  Imputed_Bhlhe40-GFP         True  3000000.0        0.0        3.0        1.0            False    False
# CD102                              Imputed_CD102         True  3000000.0        0.0        3.0        1.0            False    False
# CD107a                            Imputed_CD107a         True  3000000.0        0.0        3.0        1.0            False    False
# CD115                              Imputed_CD115         True  3000000.0        0.0        3.0        1.0            False    False
# CD11a                              Imputed_CD11a         True  3000000.0        0.0        3.0        1.0            False    False
# CD11c                              Imputed_CD11c         True  3000000.0        0.0        3.0        1.0            False    False
# CD123                              Imputed_CD123         True  3000000.0        0.0        3.0        1.0            False    False
# CD124                              Imputed_CD124         True  3000000.0        0.0        3.0        1.0            False    False
# CD126                              Imputed_CD126         True  3000000.0        0.0        3.0        1.0            False    False
# CD129                              Imputed_CD129         True  3000000.0        0.0        3.0        1.0            False    False
# CD137                              Imputed_CD137         True  3000000.0        0.0        3.0        1.0            False    False
# CD14                                Imputed_CD14         True  3000000.0        0.0        3.0        1.0            False    False
# CD140a                            Imputed_CD140a         True  3000000.0        0.0        3.0        1.0            False    False
# CD155                              Imputed_CD155         True  3000000.0        0.0        3.0        1.0            False    False
# CD159a                            Imputed_CD159a         True  3000000.0        0.0        3.0        1.0            False    False
# CD160                              Imputed_CD160         True  3000000.0        0.0        3.0        1.0            False    False
# CD163                              Imputed_CD163         True  3000000.0        0.0        3.0        1.0            False    False
# CD169                              Imputed_CD169         True  3000000.0        0.0        3.0        1.0            False    False
# CD170                              Imputed_CD170         True  3000000.0        0.0        3.0        1.0            False    False
# CD172a                            Imputed_CD172a         True  3000000.0        0.0        3.0        1.0            False    False
# CD182                              Imputed_CD182         True  3000000.0        0.0        3.0        1.0            False    False
# CD183                              Imputed_CD183         True  3000000.0        0.0        3.0        1.0            False    False
# CD193                              Imputed_CD193         True  3000000.0        0.0        3.0        1.0            False    False
# CD1d                                Imputed_CD1d         True  3000000.0        0.0        3.0        1.0            False    False
# CD2                                  Imputed_CD2         True  3000000.0        0.0        3.0        1.0            False    False
# CD20                                Imputed_CD20         True  3000000.0        0.0        3.0        1.0            False    False
# CD200                              Imputed_CD200         True  3000000.0        0.0        3.0        1.0            False    False
# CD200R3                          Imputed_CD200R3         True  3000000.0        0.0        3.0        1.0            False    False
# CD200r                            Imputed_CD200r         True  3000000.0        0.0        3.0        1.0            False    False
# CD204                              Imputed_CD204         True  3000000.0        0.0        3.0        1.0            False    False
# CD205                              Imputed_CD205         True  3000000.0        0.0        3.0        1.0            False    False
# CD213a1                          Imputed_CD213a1         True  3000000.0        0.0        3.0        1.0            False    False
# CD21_35                          Imputed_CD21_35         True  3000000.0        0.0        3.0        1.0            False    False
# CD22                                Imputed_CD22         True  3000000.0        0.0        3.0        1.0            False    False
# CD223                              Imputed_CD223         True  3000000.0        0.0        3.0        1.0            False    False
# CD23                                Imputed_CD23         True  3000000.0        0.0        3.0        1.0            False    False
# CD24                                Imputed_CD24         True  3000000.0        0.0        3.0        1.0            False    False
# CD25                                Imputed_CD25         True  3000000.0        0.0        3.0        1.0            False    False
# CD26                                Imputed_CD26         True  3000000.0        0.0        3.0        1.0            False    False
# CD270                              Imputed_CD270         True  3000000.0        0.0        3.0        1.0            False    False
# CD274                              Imputed_CD274         True  3000000.0        0.0        3.0        1.0            False    False
# CD278                              Imputed_CD278         True  3000000.0        0.0        3.0        1.0            False    False
# CD279                              Imputed_CD279         True  3000000.0        0.0        3.0        1.0            False    False
# CD29                                Imputed_CD29         True  3000000.0        0.0        3.0        1.0            False    False
# CD300LG                          Imputed_CD300LG         True  3000000.0        0.0        3.0        1.0            False    False
# CD301b                            Imputed_CD301b         True  3000000.0        0.0        3.0        1.0            False    False
# CD317                              Imputed_CD317         True  3000000.0        0.0        3.0        1.0            False    False
# CD357                              Imputed_CD357         True  3000000.0        0.0        3.0        1.0            False    False
# CD36                                Imputed_CD36         True  3000000.0        0.0        3.0        1.0            False    False
# CD366                              Imputed_CD366         True  3000000.0        0.0        3.0        1.0            False    False
# CD38                                Imputed_CD38         True  3000000.0        0.0        3.0        1.0            False    False
# CD43                                Imputed_CD43         True  3000000.0        0.0        3.0        1.0            False    False
# CD44                                Imputed_CD44         True  3000000.0        0.0        3.0        1.0            False    False
# CD49a                              Imputed_CD49a         True  3000000.0        0.0        3.0        1.0            False    False
# CD49b                              Imputed_CD49b         True  3000000.0        0.0        3.0        1.0            False    False
# CD49d                              Imputed_CD49d         True  3000000.0        0.0        3.0        1.0            False    False
# CD51                                Imputed_CD51         True  3000000.0        0.0        3.0        1.0            False    False
# CD54                                Imputed_CD54         True  3000000.0        0.0        3.0        1.0            False    False
# CD61                                Imputed_CD61         True  3000000.0        0.0        3.0        1.0            False    False
# CD63                                Imputed_CD63         True  3000000.0        0.0        3.0        1.0            False    False
# CD64                                Imputed_CD64         True  3000000.0        0.0        3.0        1.0            False    False
# CD69                                Imputed_CD69         True  3000000.0        0.0        3.0        1.0            False    False
# CD73                                Imputed_CD73         True  3000000.0        0.0        3.0        1.0            False    False
# CD79b                              Imputed_CD79b         True  3000000.0        0.0        3.0        1.0            False    False
# CD81                                Imputed_CD81         True  3000000.0        0.0        3.0        1.0            False    False
# CD84                                Imputed_CD84         True  3000000.0        0.0        3.0        1.0            False    False
# CD85k                              Imputed_CD85k         True  3000000.0        0.0        3.0        1.0            False    False
# CD90_2                            Imputed_CD90_2         True  3000000.0        0.0        3.0        1.0            False    False
# CD95                                Imputed_CD95         True  3000000.0        0.0        3.0        1.0            False    False
# CXCR4                              Imputed_CXCR4         True  3000000.0        0.0        3.0        1.0            False    False
# Csf1r-GFP                      Imputed_Csf1r-GFP         True  3000000.0        0.0        3.0        1.0            False    False
# ESAM                                Imputed_ESAM         True  3000000.0        0.0        3.0        1.0            False    False
# Epx-cre-tdTomato        Imputed_Epx-cre-tdTomato         True  3000000.0        0.0        3.0        1.0            False    False
# F4_80                              Imputed_F4_80         True  3000000.0        0.0        3.0        1.0            False    False
# Fucci-hCdt1-mCherry  Imputed_Fucci-hCdt1-mCherry         True  3000000.0        0.0        3.0        1.0            False    False
# Fucci-hGem-Venus        Imputed_Fucci-hGem-Venus         True  3000000.0        0.0        3.0        1.0            False    False
# Gata1-mCherry              Imputed_Gata1-mCherry         True  3000000.0        0.0        3.0        1.0            False    False
# Gata2-Venus                  Imputed_Gata2-Venus         True  3000000.0        0.0        3.0        1.0            False    False
# Gfi1-tdTomato              Imputed_Gfi1-tdTomato         True  3000000.0        0.0        3.0        1.0            False    False
# IL33r                              Imputed_IL33r         True  3000000.0        0.0        3.0        1.0            False    False
# I_A_I_E                          Imputed_I_A_I_E         True  3000000.0        0.0        3.0        1.0            False    False
# IgD                                  Imputed_IgD         True  3000000.0        0.0        3.0        1.0            False    False
# IgM                                  Imputed_IgM         True  3000000.0        0.0        3.0        1.0            False    False
# LPAM1                              Imputed_LPAM1         True  3000000.0        0.0        3.0        1.0            False    False
# Ly108                              Imputed_Ly108         True  3000000.0        0.0        3.0        1.0            False    False
# Ly49A                              Imputed_Ly49A         True  3000000.0        0.0        3.0        1.0            False    False
# Mki67-RFP                      Imputed_Mki67-RFP         True  3000000.0        0.0        3.0        1.0            False    False
# Ms4a3-cre-tdTomato    Imputed_Ms4a3-cre-tdTomato         True  3000000.0        0.0        3.0        1.0            False    False
# Myc-GFP                          Imputed_Myc-GFP         True  3000000.0        0.0        3.0        1.0            False    False
# Ncr1-GFP                        Imputed_Ncr1-GFP         True  3000000.0        0.0        3.0        1.0            False    False
# PIR_A_B                          Imputed_PIR_A_B         True  3000000.0        0.0        3.0        1.0            False    False
# Phf6_GFP                        Imputed_Phf6_GFP         True  3000000.0        0.0        3.0        1.0            False    False
# Plzf_GFP                        Imputed_Plzf_GFP         True  3000000.0        0.0        3.0        1.0            False    False
# Pu.1-YFP                        Imputed_Pu.1-YFP         True  3000000.0        0.0        3.0        1.0            False    False
# SiglecH                          Imputed_SiglecH         True  3000000.0        0.0        3.0        1.0            False    False
# TIM4                                Imputed_TIM4         True  3000000.0        0.0        3.0        1.0            False    False
# TLR4                                Imputed_TLR4         True  3000000.0        0.0        3.0        1.0            False    False
# TSLPR                              Imputed_TSLPR         True  3000000.0        0.0        3.0        1.0            False    False
# Tcf7_GFP                        Imputed_Tcf7_GFP         True  3000000.0        0.0        3.0        1.0            False    False
# Tox-tdTomato                Imputed_Tox-tdTomato         True  3000000.0        0.0        3.0        1.0            False    False
# VISTA                              Imputed_VISTA         True  3000000.0        0.0        3.0        1.0            False    False
# Wnt_GFP                          Imputed_Wnt_GFP         True  3000000.0        0.0        3.0        1.0            False    False
# CD49f                              Imputed_CD49f         True  3000000.0        0.0        3.0        1.0            False    False
# CD86                                Imputed_CD86         True  3000000.0        0.0        3.0        1.0            False    False
# CD9                                  Imputed_CD9         True  3000000.0        0.0        3.0        1.0            False    False
# CD71                                Imputed_CD71         True  3000000.0        0.0        3.0        1.0            False    False
# CD34                                Imputed_CD34         True  3000000.0        0.0        3.0        1.0            False    False
# CD62L                              Imputed_CD62L         True  3000000.0        0.0        3.0        1.0            False    False
# CD31                                Imputed_CD31         True  3000000.0        0.0        3.0        1.0            False    False

# %%
# Read in the R7 annotations (with old umap)
cell_anno = pd.read_csv("output/automated_py3_cellharmony_r7/"\
    "r7_py3_cellharmony_assigned_infinity_flow_groups_redo.csv")

# Read in the new umap coordinates
even_umap_coors = pd.read_csv("output/automated_py3_cellharmony_r7/"\
    "evenly_sampled_r7/umap_2d_coordinates_redo.csv")

cell_anno.loc[:,["umap_x", "umap_y"]] = even_umap_coors[["umap-x", "umap-y"]].values

cell_anno
# Out:
#           cell_id  cell_number     umap_x     umap_y              r7    r7_rho
# 0              :0            0  10.952296  -6.878245    preNeu-3-ADT  0.836751
# 1              :1            1  10.202045   7.717799  pre-MultiLin-1  0.903928
# 2              :2            2  12.240065  -3.202506        preNeu-1  0.793765
# 3              :3            3   6.748181  21.352978     pre-B-Il2ra  0.874901
# 4              :4            4   9.314702   5.906703        ETP-CC-4  0.925663
# ...           ...          ...        ...        ...             ...       ...
# 1935032  :1935032      1935032  -4.400203  -1.029844    ERP4-Bcl2l15  0.556924
# 1935033  :1935033      1935033  12.978972  -5.007983        preNeu-1  0.410792
# 1935034  :1935034      1935034  10.876128   5.335987      MultiLin-1  0.464509
# 1935035  :1935035      1935035   5.310091  -2.056845            Baso  0.742290
# 1935036  :1935036      1935036  14.387283   6.744263        MDP-Irf8  0.379571
#
# [1935037 rows x 6 columns]

# %%
# Get r7 centroid positions
pd.pivot_table(cell_anno, index="r7", values=["umap_x", "umap_y"], aggfunc=np.mean).to_csv(\
    "output/automated_py3_cellharmony_r7/evenly_sampled_r7/plots_for_pub/"\
    "r7_centroid_positions_over_evenly_sampled_umap.csv",
    header=True, index=True)

# %%
# Read in the previously used mapping from R7 to number for FCS file
r7_num_anno = pd.read_csv("output/automated_py3_cellharmony_r7/fcs/"\
    "r7_to_number_cluster_mapping_redo.csv", header=None)

r7_to_num = pd.Series(\
    r7_num_anno.iloc[:,1].values, 
    index=r7_num_anno.iloc[:,0].values)

r7_to_num
# Out:
# B-cell progenitor        1
# BMCP                     2
# Baso                     3
# Bcl11b+_preETP_Cd3d      4
# Bcl11b+_preETP_Tdrd5     5
#                         ..
# preNeu-3-Mac_C1qa       84
# preNeu-Ebf1             85
# proNeu-1                86
# proNeu-1-ADT            87
# proNeu-2                88
# Length: 88, dtype: int64

# %%
# Features to take from the old FCS object
var_to_drop = ["umap-x", "umap-y"]
inflow_X = tmp_fcs[:,np.setdiff1d(tmp_fcs.var.index.values, var_to_drop)]

# Features to add to the FCS
to_add_X_df = pd.DataFrame({\
    "umap_x": cell_anno["umap_x"].values,
    "umap_y": cell_anno["umap_y"].values,
    "R7": cell_anno["r7"].replace(r7_to_num.to_dict()).values,
    "cell_number": list(range(1,1+cell_anno.shape[0]))})

old_var = tmp_fcs[:,np.setdiff1d(tmp_fcs.var.index.values, var_to_drop)].var
old_var.loc["leiden", "USE_LOGICLE"] = False

to_add_var = pd.DataFrame(\
    old_var.loc[['leiden']*4].values,
    columns = old_var.columns.values,
    index = to_add_X_df.columns.values)

new_flow = anndata.AnnData(\
    X = np.concatenate([\
        inflow_X.X.toarray(),
        to_add_X_df.values], 
        axis=1),
    obs = tmp_fcs.obs,
    var = pd.concat([old_var, to_add_var]))

new_flow
# Out:
# /tmp/ipykernel_623884/3180419335.py:20: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   new_flow = anndata.AnnData(\
# AnnData object with n_obs × n_vars = 1935037 × 151
#     obs: 'cell_number'
#     var: 'name', 'USE_LOGICLE', 'LOGICLE_T', 'LOGICLE_W', 'LOGICLE_M', 'LOGICLE_A', 'LOGICLE_APPLIED', 'IMPUTED'

# %%
from pyInfinityFlow.InfinityFlow_Utilities import write_anndata_to_fcs

write_anndata_to_fcs(\
    new_flow, 
    "output/automated_py3_cellharmony_r7/evenly_sampled_r7/fcs_for_pub/"\
        "optimized_infinityflow_with_even_sampled_fcs_and_r7_labels.fcs",
    add_umap = False)
# Out:
# Omitting spillover matrix...
# WARNING! TEXT segment value for key $P1S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P100S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P101S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P102S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P132S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P133S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P134S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P135S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P136S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P137S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P143S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P147S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P148S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P149S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P150S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P151S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P1S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P100S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P101S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P102S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P132S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P133S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P134S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P135S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P136S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P137S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P143S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P147S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P148S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P149S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P150S is empty. Excluding from written file.
# WARNING! TEXT segment value for key $P151S is empty. Excluding from written file.
