# %%
import os
import pandas as pd
import numpy as np
import scanpy as sc
import anndata
from scipy import stats
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Arial"
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import gc

os.chdir("/media/kyle_storage/kyle_ferchen/grimes_lab_main/analysis/2023_06_12_tea_seq_atac_processing/")

path_cite_data = "/media/kyle_storage/kyle_ferchen/grimes_lab_main/data/"\
    "2021_11_mouse_optimized_cite_seq/processed_files/"

# %%
## Helper functions
def pearson_corr_df_to_df(df1, df2):
    norm1 = df1 - df1.mean(axis=0)
    norm2 = df2 - df2.mean(axis=0)
    sqsum1 = (norm1**2).sum(axis=0)
    sqsum2 = (norm2**2).sum(axis=0)
    return((norm1.T @ norm2) / np.sqrt(sqsum1.apply(lambda x: x*sqsum2)))

# %%
new_cluster_order = pd.read_csv("/media/kyle_storage/kyle_ferchen/"\
    "grimes_lab_main/data/2021_11_mouse_optimized_cite_seq/processed_files/"\
    "r7_cluster_order_kf_2024_01.csv")
map_r7_to_lv3 = pd.Series(\
    new_cluster_order["Level 3"].values,
    index=new_cluster_order["Cluster"].values)
map_lvl3_to_order = pd.Series(\
    new_cluster_order["Order"].values,
    index=new_cluster_order["Level 3"].values)
map_r7_to_replace_dash = pd.Series(\
    new_cluster_order["Cluster"].values,
    index=[i.replace("-", "_") for i in new_cluster_order["Cluster"].values])
new_cluster_order
# Out:
#                  Cluster     Group  Old_order           CITE-to-TEA  Order  \
# 0           LT-HSC_Mllt3      HSCP          1          LT-HSC_Mllt3    1.0
# 1                 ST-HSC      HSCP          2                ST-HSC    2.0
# 2               MPP4-Hlf      HSCP          3              MPP4-Hlf    3.0
# 3              MPP5-Egr1      HSCP          8             MPP5-Egr1    4.0
# 4              MPP5-Flt3      HSCP          7             MPP5-Flt3    5.0
# ..                   ...       ...        ...                   ...    ...
# 83                  ILC2       ILC         84                  ILC2   84.0
# 84   Bcl11b+_preETP_Cd3d       ILC         85   Bcl11b+_preETP_Cd3d   85.0
# 85  Bcl11b+_preETP_Tdrd5       ILC         88  Bcl11b+_preETP_Tdrd5   86.0
# 86         ILC1-ILC3-NKP       ILC         87         ILC1-ILC3-NKP   87.0
# 87               MEP-UNK  MultiLin         22               MEP-UNK    NaN
#
#      Level 1 Level 2            Level 3 Level Kairavee
# 0       HSPC     HSC               qHSC            HSC
# 1       HSPC     HSC               aHSC            HSC
# 2       HSPC    MPP4             HSC-Ly           HSPC
# 3       HSPC    MPP5           MPP5-IER       MPP5-IER
# 4       HSPC    MPP5          MPP5 Ly-I           HSPC
# ..       ...     ...                ...            ...
# 83       ILC     ILC               ILC2            ILC
# 84    T cell  preETP  pre-ILC1-ILC3-NKP         preETP
# 85    T cell  preETP            pre-NKP         preETP
# 86       ILC     ILC      ILC1-ILC3-NKP            ILC
# 87  MultiLin     MEP            MEP-UNK            NaN
#
# [88 rows x 9 columns]

# %%
# Seqlet annotation
seqlets = pd.read_feather("output/chrombpnet/modisco_merged_results/fold_0/"\
    "redo_extract_seqlets/all_seqlit_hits_above_modisco_min_anno.fea")

# Seqlets
dp_scores = pd.read_feather("output/chrombpnet/modisco_merged_results/fold_0/"\
    "redo_extract_seqlets/all_seqlit_hits_above_modisco_min_dp_scores.fea")
dp_scores = dp_scores.set_index("index").astype(np.float32)
dp_scores = dp_scores.rename(map_r7_to_replace_dash.to_dict(), axis=1)
dp_scores = dp_scores.rename(map_r7_to_lv3.to_dict(), axis=1)

# %%
sig_conns = pd.read_csv("output/chrombpnet/modisco_merged_results/fold_0/"\
    "redo_extract_seqlets/correlate_seqlets_to_gene_expression/sig_conns.csv")

sig_conns
# Out:
#             Gene  seqlet_idx         r
# 0         Mrpl15     1856496  0.441411
# 1         Mrpl15     1856497  0.467160
# 2         Mrpl15     2458694  0.544898
# 3         Mrpl15     2807710  0.544757
# 4         Mrpl15     3763246  0.544713
# ...          ...         ...       ...
# 22706190    Hccs    14808102  0.621244
# 22706191    Hccs    14808105  0.430966
# 22706192    Hccs    15314097  0.439063
# 22706193    Hccs    15796481  0.439211
# 22706194    Hccs    16097276  0.439197
#
# [22706195 rows x 3 columns]

# %%
# Load CITE-seq data (SoupX 0.15 corrected)
path_to_cite_data = "/media/kyle_storage/kyle_ferchen/grimes_lab_main/data/"\
    "2021_11_mouse_optimized_cite_seq/processed_files/"

cite_adata = anndata.read_h5ad(os.path.join(\
    path_to_cite_data,
    "cite_seq_adata_rna_combined_SoupX_0_15_with_R7_clusters.h5ad"))

cite_adata.X = np.log2((10000 * (cite_adata.X.T / \
    cite_adata.X.sum(axis=1).T).T) + 1)

cite_adata.obs["lvl3"] = cite_adata.obs["R7"].replace(\
    map_r7_to_lv3.to_dict()).values
cite_adata.obs["cluster_order"] = cite_adata.obs["lvl3"].replace(\
    map_lvl3_to_order.to_dict()).values

cite_adata = cite_adata[\
    cite_adata.obs.loc[cite_adata.obs["lvl3"] != "MEP-UNK"].sort_values(\
        by="cluster_order").index.values,
    :]

cite_df = pd.DataFrame(\
    cite_adata.X,
    index=cite_adata.obs.index.values,
    columns=cite_adata.var.index.values)

cite_rna = cite_df.copy()
cite_rna["cluster"] = cite_adata.obs.loc[\
    cite_rna.index.values, "lvl3"].values
cite_rna = pd.pivot_table(cite_rna, index="cluster", aggfunc=np.mean)

# %%
# Read in the surface protein expression results
# surface marker annotation
sm_anno = pd.read_csv("input/surface_protein_info/cell_surface_go_terms.csv")
sm_gene_list = sorted(sm_anno["Symbol"].unique())
sm_gene_list
# Out:
# ['Aamp',
#  'Abca1',
#  'Abca7',
#  'Abcb11',
#  'Abcb1a',
#  'Abcb1b',
#  'Abcc2',
#  'Abcc4',
#  'Abcg1',
#  'Abcg2',
#  'Ace',
#  'Ace2',
#  'Ache',
#  'Ackr3',
#  'Acvr1b',
#  'Acvr1c',
#  'Acvr2a',
#  'Acvrl1',
#  'Ada',
#  'Adam10',
#  'Adam15',
#  'Adam17',
#  'Adam19',
#  'Adam2',
#  'Adam24',
#  'Adam26a',
#  'Adam28',
#  'Adam29',
#  'Adam3',
#  'Adam30',
#  'Adam4',
#  'Adam6a',
#  'Adam8',
#  'Adam9',
#  'Adamts15',
#  'Adamts7',
#  'Adamts9',
#  'Adcyap1r1',
#  'Adgra2',
#  'Adgra3',
#  'Adgre1',
#  'Adgre4',
#  'Adgre5',
#  'Adgrf5',
#  'Adgrg6',
#  'Adgrv1',
#  'Adipoq',
#  'Adora2b',
#  'Adra2b',
#  'Adtrp',
#  'Agap2',
#  'Ager',
#  'Agrn',
#  'Aimp1',
#  'Ajap1',
#  'Akp3',
#  'Alcam',
#  'Alpi',
#  'Ambp',
#  'Amelx',
#  'Amot',
#  'Angptl3',
#  'Ank3',
#  'Ano1',
#  'Anpep',
#  'Antxr1',
#  'Antxr2',
#  'Anxa1',
#  'Anxa2',
#  'Anxa4',
#  'Anxa5',
#  'Anxa9',
#  'Aoc3',
#  'Apmap',
#  'Apoa1',
#  'Apoa4',
#  'Apoe',
#  'Apoh',
#  'App',
#  'Aqp11',
#  'Aqp4',
#  'Areg',
#  'Arpc2',
#  'Arsa',
#  'Arsb',
#  'Art1',
#  'Art2a',
#  'Art2b',
#  'Asic1',
#  'Astn1',
#  'Atp1a2',
#  'Atp1a3',
#  'Atp1b2',
#  'Atp5f1a',
#  'Atp5f1b',
#  'Atp5if1',
#  'Atp5pf',
#  'Atp5po',
#  'Atp6ap2',
#  'Axl',
#  'B2m',
#  'B4galt1',
#  'Bace1',
#  'Bcam',
#  'Bcan',
#  'Bgn',
#  'Bmp10',
#  'Bmp2',
#  'Bmpr1a',
#  'Bmpr2',
#  'Boc',
#  'Bsn',
#  'Bsph1',
#  'Bst2',
#  'Btla',
#  'Btn2a2',
#  'Btnl1',
#  'C1qbp',
#  'C3',
#  'C5ar1',
#  'Cacna1c',
#  'Cacna1d',
#  'Cacng2',
#  'Cacng4',
#  'Calr',
#  'Capn2',
#  'Capn5',
#  'Car4',
#  'Casr',
#  'Cav1',
#  'Cav2',
#  'Cav3',
#  'Ccl19',
#  'Ccl21b',
#  'Ccn5',
#  'Ccr1',
#  'Ccr10',
#  'Ccr1l1',
#  'Ccr2',
#  'Ccr4',
#  'Ccr5',
#  'Ccr6',
#  'Ccr7',
#  'Ccr9',
#  'Cd14',
#  'Cd151',
#  'Cd163',
#  'Cd19',
#  'Cd1d1',
#  'Cd1d2',
#  'Cd2',
#  'Cd200',
#  'Cd200r1',
#  'Cd200r1l',
#  'Cd200r2',
#  'Cd200r3',
#  'Cd200r4',
#  'Cd209a',
#  'Cd209b',
#  'Cd209c',
#  'Cd209d',
#  'Cd209e',
#  'Cd22',
#  'Cd226',
#  'Cd244a',
#  'Cd24a',
#  'Cd27',
#  'Cd274',
#  'Cd276',
#  'Cd28',
#  'Cd33',
#  'Cd34',
#  'Cd36',
#  'Cd38',
#  'Cd3e',
#  'Cd4',
#  'Cd40',
#  'Cd40lg',
#  'Cd44',
#  'Cd46',
#  'Cd47',
#  'Cd48',
#  'Cd5',
#  'Cd53',
#  'Cd55',
#  'Cd55b',
#  'Cd59a',
#  'Cd59b',
#  'Cd5l',
#  'Cd6',
#  'Cd63',
#  'Cd69',
#  'Cd74',
#  'Cd79a',
#  'Cd79b',
#  'Cd80',
#  'Cd83',
#  'Cd86',
#  'Cd8a',
#  'Cd8b1',
#  'Cd9',
#  'Cd93',
#  'Cd99',
#  'Cd99l2',
#  'Cdh1',
#  'Cdh13',
#  'Cdh17',
#  'Cdh2',
#  'Cdh5',
#  'Cdon',
#  'Ceacam1',
#  'Ceacam2',
#  'Cfh',
#  'Cftr',
#  'Chrd',
#  'Chrna1',
#  'Chrna4',
#  'Chrna7',
#  'Chrnb2',
#  'Ciita',
#  'Ckap4',
#  'Clcn3',
#  'Clec12a',
#  'Clec12b',
#  'Clec14a',
#  'Clec1b',
#  'Clec2d',
#  'Clec2e',
#  'Clec2f',
#  'Clec2g',
#  'Clec2h',
#  'Clec2i',
#  'Clec4b2',
#  'Clec5a',
#  'Clec7a',
#  'Clec9a',
#  'Clic4',
#  'Clptm1',
#  'Clstn1',
#  'Clstn2',
#  'Clstn3',
#  'Clu',
#  'Cntnap2',
#  'Col23a1',
#  'Corin',
#  'Cp',
#  'Cr1l',
#  'Cr2',
#  'Crhr2',
#  'Cripto',
#  'Crlf2',
#  'Cryab',
#  'Csf1r',
#  'Cst8',
#  'Ctla4',
#  'Ctnnd1',
#  'Ctsb',
#  'Ctsk',
#  'Ctsl',
#  'Ctss',
#  'Ctsz',
#  'Cx3cl1',
#  'Cx3cr1',
#  'Cxcl10',
#  'Cxcl12',
#  'Cxcl9',
#  'Cxcr2',
#  'Cxcr3',
#  'Cxcr4',
#  'Cxcr5',
#  'Cyp2w1',
#  'Dag1',
#  'Dcbld2',
#  'Dcstamp',
#  'Defb22',
#  'Dip2a',
#  'Dlk1',
#  'Dmd',
#  'Dnai2',
#  'Dpp4',
#  'Dpp6',
#  'Drd1',
#  'Dscaml1',
#  'Duox1',
#  'Duox2',
#  'Ece1',
#  'Efna5',
#  'Efnb1',
#  'Egfr',
#  'Elane',
#  'Emp2',
#  'Eng',
#  'Eno1',
#  'Eno1b',
#  'Eno2',
#  'Enox1',
#  'Enox2',
#  'Enpep',
#  'Enpp1',
#  'Enpp3',
#  'Entpd1',
#  'Entpd2',
#  'Entpd6',
#  'Epcam',
#  'Epha2',
#  'Epha4',
#  'Epha5',
#  'Ephb2',
#  'Ephb6',
#  'Epo',
#  'Epor',
#  'Eppin',
#  'Erp29',
#  'Erp44',
#  'F2',
#  'F2r',
#  'F3',
#  'Fam234a',
#  'Fap',
#  'Fas',
#  'Fasl',
#  'Fcer1a',
#  'Fcer1g',
#  'Fcer2a',
#  'Fcgr1',
#  'Fcgr2b',
#  'Fcgr3',
#  'Fcgr4',
#  'Fcmr',
#  'Fcrl1',
#  'Fcrl2',
#  'Fcrl5',
#  'Fcrl6',
#  'Fga',
#  'Fgb',
#  'Fgf10',
#  'Fgf22',
#  'Fgf8',
#  'Fgfbp1',
#  'Fgfr2',
#  'Fgfr3',
#  'Fgg',
#  'Flot1',
#  'Flt3',
#  'Flt3l',
#  'Folh1',
#  'Folr1',
#  'Folr2',
#  'Fshr',
#  'Furin',
#  'Fut4',
#  'Fzd1',
#  'Fzd10',
#  'Fzd4',
#  'Fzd5',
#  'Fzd9',
#  'Gabrb3',
#  'Gfra1',
#  'Gfra3',
#  'Gfral',
#  'Ghr',
#  'Ghrhr',
#  'Ghsr',
#  'Gjd3',
#  'Gldn',
#  'Glra1',
#  'Glrb',
#  'Got2',
#  'Gp1ba',
#  'Gp2',
#  'Gp5',
#  'Gp6',
#  'Gpc4',
#  'Gpihbp1',
#  'Gpr37',
#  'Gprc5b',
#  'Gprc6a',
#  'Grem1',
#  'Gria1',
#  'Gria2',
#  'Grin1',
#  'Grin2a',
#  'Grin2b',
#  'Grm7',
#  'Gsr',
#  'Gucy2g',
#  'Gypa',
#  'H13',
#  'H1f1',
#  'H2-Aa',
#  'H2-Ab1',
#  'H2-D1',
#  'H2-DMa',
#  'H2-Ea',
#  'H2-Eb1',
#  'H2-Eb2',
#  'H2-K1',
#  'H2-L',
#  'H2-M1',
#  'H2-M10.1',
#  'H2-M10.2',
#  'H2-M10.3',
#  'H2-M10.4',
#  'H2-M10.5',
#  'H2-M10.6',
#  'H2-M11',
#  'H2-M2',
#  'H2-M3',
#  'H2-M5',
#  'H2-M9',
#  'H2-Q1',
#  'H2-Q10',
#  'H2-Q2',
#  'H2-Q4',
#  'H2-Q6',
#  'H2-Q7',
#  'H2-Q8',
#  'H2-Q9',
#  'H2-T10',
#  'H2-T11-ps',
#  'H2-T13',
#  'H2-T15',
#  'H2-T22',
#  'H2-T23',
#  'H2-T3',
#  'H2-T5',
#  'H2-T7',
#  'H2-T9',
#  'H2bc1',
#  'H60a',
#  'Havcr1',
#  'Havcr2',
#  'Hbegf',
#  'Hcn1',
#  'Hcst',
#  'Heg1',
#  'Hfe',
#  'Hhip',
#  'Hilpda',
#  'Hjv',
#  'Hmgb1',
#  'Hnrnpm',
#  'Hnrnpu',
#  'Hpn',
#  'Hrg',
#  'Hsp90aa1',
#  'Hsp90ab1',
#  'Hspa2',
#  'Hspa5',
#  'Hspa8',
#  'Hspd1',
#  'Htr2c',
#  'Htr3b',
#  'Hyal2',
#  'Hyal4',
#  'Hyal5',
#  'Icam1',
#  'Icos',
#  'Icosl',
#  'Ide',
#  'Ifitm3',
#  'Ifng',
#  'Igf2r',
#  'Ighd',
#  'Ighg1',
#  'Ighm',
#  'Iglc1',
#  'Igsf21',
#  'Igsf5',
#  'Il12a',
#  'Il12b',
#  'Il12rb1',
#  'Il12rb2',
#  'Il13',
#  'Il13ra2',
#  'Il15',
#  'Il15ra',
#  'Il17a',
#  'Il17rb',
#  'Il17rc',
#  'Il1a',
#  'Il1r1',
#  'Il1rapl1',
#  'Il1rl1',
#  'Il27',
#  'Il2ra',
#  'Il2rb',
#  'Il2rg',
#  'Il31ra',
#  'Il4',
#  'Il6',
#  'Il6ra',
#  'Il6st',
#  'Il7r',
#  'Il9r',
#  'Insr',
#  'Iqgap2',
#  'Irak1',
#  'Irak4',
#  'Islr2',
#  'Itga1',
#  'Itga2',
#  'Itga2b',
#  'Itga3',
#  'Itga4',
#  'Itga5',
#  'Itga6',
#  'Itga7',
#  'Itga8',
#  'Itgae',
#  'Itgal',
#  'Itgam',
#  'Itgav',
#  'Itgax',
#  'Itgb1',
#  'Itgb2',
#  'Itgb2l',
#  'Itgb3',
#  'Itgb4',
#  'Itgb5',
#  'Itgb6',
#  'Itgb7',
#  'Itgb8',
#  'Jam2',
#  'Jam3',
#  'Kcna1',
#  'Kcna4',
#  'Kcna5',
#  'Kcnb1',
#  'Kcnc1',
#  'Kcnc4',
#  'Kcne1',
#  'Kcne2',
#  'Kcnh1',
#  'Kcnh2',
#  'Kcnh5',
#  'Kcnj3',
#  'Kcnj5',
#  'Kcnj6',
#  'Kcnk2',
#  'Kcnma1',
#  'Kcnn2',
#  'Kcnq2',
#  'Kcnq3',
#  'Kdr',
#  'Kiss1r',
#  'Kit',
#  'Klra1',
#  'Klra4',
#  'Klra7',
#  'Klra8',
#  'Klrb1b',
#  'Klrb1c',
#  'Klrb1f',
#  'Klrc1',
#  'Klrc2',
#  'Klrc3',
#  'Klrd1',
#  'Klre1',
#  'Klrk1',
#  'Krt18',
#  'Krt4',
#  'L1cam',
#  'Lag3',
#  'Lamp1',
#  'Lbp',
#  'Lct',
#  'Ldlr',
#  'Lgals1',
#  'Lgals3',
#  'Lilra5',
#  'Lilrb4a',
#  'Lilrb4b',
#  'Lipc',
#  'Lipg',
#  'Lman2',
#  'Lmo7',
#  'Lnpep',
#  'Lpar1',
#  'Lpar2',
#  'Lpl',
#  'Lrfn1',
#  'Lrfn2',
#  'Lrfn3',
#  'Lrfn4',
#  'Lrfn5',
#  'Lrp1',
#  'Lrp2',
#  'Lrp4',
#  'Lrp6',
#  'Lrp8',
#  'Lrrc15',
#  'Lrrc32',
#  'Lrrc8a',
#  'Ltf',
#  'Ly6a',
#  'Ly6c1',
#  'Ly6c2',
#  'Ly6d',
#  'Ly6g',
#  'Ly6g5b',
#  'Ly6g5c',
#  'Ly6g6c',
#  'Ly6g6d',
#  'Ly6k',
#  'Ly75',
#  'Ly9',
#  'Lyn',
#  'Lypla1',
#  'Map3k5',
#  'Mas1',
#  'Mbp',
#  'Mcam',
#  'Meltf',
#  'Mfge8',
#  'Mif',
#  'Mill1',
#  'Mill2',
#  'Mmp25',
#  'Mmp7',
#  'Mog',
#  'Mpl',
#  'Mrc1',
#  'Mrc2',
#  'Ms4a1',
#  'Ms4a2',
#  'Msln',
#  'Msn',
#  'Muc1',
#  'Muc16',
#  'Muc17',
#  'Musk',
#  'Mxra8',
#  'Myd88',
#  'Ncam1',
#  'Ncl',
#  'Ncr1',
#  'Ndp',
#  'Nectin2',
#  'Neo1',
#  'Neu1',
#  'Neu3',
#  'Nfam1',
#  'Ngfr',
#  'Nid2',
#  'Nlgn1',
#  'Nlgn2',
#  'Nlgn3',
#  'Nlgn4l',
#  'Nod2',
#  'Notch1',
#  'Notch2',
#  'Notch4',
#  'Nptn',
#  'Nrg1',
#  'Nrp1',
#  'Nrros',
#  'Nrxn1',
#  'Nt5e',
#  'Ntm',
#  'Ntrk1',
#  'Ntrk2',
#  'Ntsr1',
#  'Ntsr2',
#  'Ocln',
#  'Ofa',
#  'Oscar',
#  'Osmr',
#  'P2rx1',
#  'P2rx2',
#  'P2rx7',
#  'P2ry12',
#  'P4hb',
#  'Pam',
#  'Pcsk6',
#  'Pcsk9',
#  'Pdcd1',
#  'Pdgfa',
#  'Pdgfb',
#  'Pdgfc',
#  'Pdgfra',
#  'Pdgfrb',
#  'Pdia3',
#  'Pdia4',
#  'Pdpn',
#  'Pebp1',
#  'Pecam1',
#  'Phb1',
#  'Phb2',
#  'Picalm',
#  'Pirb',
#  'Pkd1',
#  'Pkd1l3',
#  'Pkd2l1',
#  'Pla2g1b',
#  'Pla2g5',
#  'Pla2r1',
#  'Plat',
#  'Plau',
#  'Plaur',
#  'Plet1',
#  'Plg',
#  'Plppr4',
#  'Plvap',
#  'Plxnb3',
#  'Pmp22',
#  'Prlr',
#  'Prn',
#  'Prnd',
#  'Prnp',
#  'Prom1',
#  'Prom2',
#  'Prss8',
#  'Psen1',
#  'Psg16',
#  'Psg20',
#  'Ptger3',
#  'Ptn',
#  'Ptprc',
#  'Ptprj',
#  'Ptprk',
#  'Ptprt',
#  'Pvr',
#  'Pxdn',
#  'Raet1b',
#  'Raet1c',
#  'Raet1d',
#  'Rala',
#  'Ramp1',
#  'Ramp2',
#  'Ramp3',
#  'Rc3h2',
#  'Rer1',
#  'Rgma',
#  'Rnpep',
#  'Robo1',
#  'Robo2',
#  'Robo4',
#  'Ror1',
#  'Ror2',
#  'Rorc',
#  'Ros1',
#  'Rps6kb1',
#  'Rs1',
#  'Rspo2',
#  'Rtbdn',
#  'Rtn2',
#  'Rtn4r',
#  'Rtn4rl1',
#  'Rtn4rl2',
#  'Rtp1',
#  'Rtp2',
#  'S100a10',
#  'S1pr1',
#  'Sarm1',
#  'Scara5',
#  'Scarb1',
#  'Scart2',
#  'Scn5a',
#  'Scnn1a',
#  'Scnn1b',
#  'Scnn1g',
#  'Scube1',
#  'Scube3',
#  'Sdc1',
#  'Sdc4',
#  'Sell',
#  'Selp',
#  'Sema6c',
#  'Sema6d',
#  'Sema7a',
#  'Septin2',
#  'Serpina5',
#  'Serpinf2',
#  'Sfrp1',
#  'Sfrp4',
#  'Shh',
#  'Siglece',
#  'Siglech',
#  'Sirpa',
#  'Slamf1',
#  'Slamf7',
#  'Slamf9',
#  'Slc11a1',
#  'Slc11a2',
#  'Slc12a1',
#  'Slc1a1',
#  'Slc1a2',
#  'Slc1a3',
#  'Slc24a1',
#  'Slc26a9',
#  'Slc2a4',
#  'Slc32a1',
#  'Slc34a1',
#  'Slc38a1',
#  'Slc3a2',
#  'Slc46a2',
#  'Slc4a1',
#  'Slc4a3',
#  'Slc4a4',
#  'Slc6a1',
#  'Slc6a2',
#  'Slc6a3',
#  'Slc7a11',
#  'Slc7a5',
#  'Slc9a1',
#  'Slco3a1',
#  'Slit2',
#  'Slitrk3',
#  'Slitrk6',
#  'Smim1',
#  'Sorl1',
#  'Sort1',
#  'Spa17',
#  'Spag11a',
#  'Spam1',
#  'Sparc',
#  'Spn',
#  'Sptb',
#  'Srpx2',
#  'St14',
#  'Stab2',
#  'Stx2',
#  'Stx4a',
#  'Sucnr1',
#  'Sulf1',
#  'Sulf2',
#  'Synj2bp',
#  'Tacr1',
#  'Tas2r118',
#  'Tcn2',
#  'Tcra',
#  'Tcra-V2',
#  'Tcra-V3.1',
#  'Tcrb',
#  'Tcrb-C',
#  'Tcrd',
#  'Tcrg',
#  'Tek',
#  'Tex101',
#  'Tfpi',
#  'Tfr2',
#  'Tfrc',
#  'Tgfa',
#  'Tgfb1',
#  'Tgfb2',
#  'Tgfb3',
#  'Tgfbr1',
#  'Tgfbr2',
#  'Tgfbr3',
#  'Thbd',
#  'Thbs1',
#  'Thsd1',
#  'Thy1',
#  'Tigit',
#  'Timd2',
#  'Timp2',
#  'Tirap',
#  'Tjp1',
#  'Tjp2',
#  'Tjp3',
#  'Tlr2',
#  'Tlr3',
#  'Tlr4',
#  'Tlr8',
#  'Tmc1',
#  'Tmem102',
#  'Tmem123',
#  'Tmem8b',
#  'Tmigd1',
#  'Tmprss11d',
#  'Tmprss11f',
#  'Tmx3',
#  'Tnf',
#  'Tnfrsf10b',
#  'Tnfrsf11a',
#  'Tnfrsf12a',
#  'Tnfrsf13b',
#  'Tnfrsf13c',
#  'Tnfrsf14',
#  'Tnfrsf18',
#  'Tnfrsf1a',
#  'Tnfrsf22',
#  'Tnfrsf23',
#  'Tnfrsf4',
#  'Tnfrsf9',
#  'Tnfsf13',
#  'Tnfsf18',
#  'Tnfsf4',
#  'Tnn',
#  'Tnr',
#  'Tpo',
#  'Trdc',
#  'Trem1',
#  'Trem2',
#  'Treml1',
#  'Treml2',
#  'Trf',
#  'Trgv3',
#  'Trgv5',
#  'Trhr',
#  'Trpc4',
#  'Trpm8',
#  'Trpv1',
#  'Trpv2',
#  'Trpv4',
#  'Tspan14',
#  'Tspan15',
#  'Tspan32',
#  'Tspan33',
#  'Tspan8',
#  'Tspear',
#  'Tyro3',
#  'Tyrobp',
#  'Ulbp1',
#  'Umodl1',
#  'Unc5d',
#  'Upk1a',
#  'Usp14',
#  'Vamp1',
#  'Vamp3',
#  'Vamp4',
#  'Vamp5',
#  'Vamp7',
#  'Vamp8',
#  'Vasn',
#  'Vcam1',
#  'Vcan',
#  'Vegfa',
#  'Vldlr',
#  'Vpreb1a',
#  'Vsir',
#  'Vtcn1',
#  'Vwf',
#  'Wfdc6a',
#  'Wnt1',
#  'Wnt3a',
#  'Wnt4',
#  'Wnt5a',
#  'Wnt5b',
#  'Wnt6',
#  'Wnt7a',
#  'Wnt7b',
#  'Zdhhc5',
#  'Zzef1']

# %%
### Read in the results from previous analysis of seqlet to gene expression cor
## Gene clusters: hierarchical clusturing across seqlet to gene r values
# Read in the gene clusters
gene_clusters = pd.read_csv(\
    "output/chrombpnet/modisco_merged_results/fold_0/redo_extract_seqlets/WITH_ALL_GENES/"\
    "seqlet_to_gene_expression_correlation_gene_clusters.csv",
    header=None, index_col=0)
gene_clusters.index.name = None
## Seqlet clusters: MarkerFinder to hierarchical gene clusters
# Read in the seqlet clusters
marker_df = pd.read_csv(\
    "output/chrombpnet/modisco_merged_results/fold_0/redo_extract_seqlets/WITH_ALL_GENES/"\
    "seqlet_to_gene_expression_correlation_seqlet_markerfinder.csv")

marker_df["pattern"] = seqlets.loc[marker_df["seqlet_idx"].values, "pattern"].values

# %%
sm_gene_clusters = gene_clusters.loc[\
    pd.Series(gene_clusters.index.values).isin(sm_gene_list).values].copy()
sm_gene_clusters
# Out:
#            1
# Alcam      1
# Entpd1     2
# Il15       2
# Cd1d1      3
# Mfge8      5
# ...      ...
# Ccr1     169
# Fcer1a   169
# Cdh1     169
# Cd200r3  169
# Ms4a2    169
#
# [259 rows x 1 columns]

# %%
gene_clusters
# Out:
#                  1
# Tgfbi            1
# Tapbp            1
# Ubl3             1
# Il21r            1
# Tgoln1           1
# ...            ...
# Riok3          170
# 4930438A08Rik  170
# Slfn4          170
# BC005561       170
# Igll1          170
#
# [4601 rows x 1 columns]

# %%
# Read in the TEA-seq markergene list
selected_markers_tea = pd.read_csv("output/chrombpnet/modisco_merged_results/"\
    "fold_0/redo_extract_seqlets/WITH_ALL_GENES/"\
    "marker_genes_tea_seq_cbpnet_clusters_n_50_corr_0_2.csv")

# %%
seqlets_to_sm_genes = marker_df.loc[\
    marker_df["seqlet_idx"].isin(sig_conns.loc[sig_conns["Gene"].isin(\
        sm_gene_clusters.index.values), "seqlet_idx"].values)]

# %%
# Recalculate corr df based on gene clusters and filtered seqlets
cor_df = pearson_corr_df_to_df(\
    cite_rna.loc[\
        dp_scores.columns.values,
        sm_gene_clusters.index.values],
    dp_scores.loc[\
        seqlets_to_sm_genes["seqlet_idx"].values,:].T)

# %%
print(sm_gene_clusters.to_string())
# Out:
#              1
# Alcam        1
# Entpd1       2
# Il15         2
# Cd1d1        3
# Mfge8        5
# H2-D1        5
# Iqgap2       5
# Adam9        6
# Cd27         6
# Ptprc        6
# Crlf2        6
# Anxa5        6
# Itgb5        8
# H2-M3        8
# Abca1        9
# Clec2d      10
# H2-Ab1      10
# Tgfbr2      10
# Igf2r       11
# Prnp        11
# Clcn3       11
# Kit         12
# S1pr1       12
# Furin       12
# H2-T23      12
# Notch2      12
# Timp2       12
# Treml2      14
# Cr1l        15
# H2-Q4       16
# Abcg1       17
# Anxa4       17
# B2m         17
# H2-T22      17
# Ifitm3      17
# Tnfrsf18    18
# Krt18       19
# Ece1        20
# Ptprj       21
# H2-Q6       21
# Mpl         22
# Synj2bp     22
# Bmpr2       26
# H2-K1       27
# Il2rg       29
# Nrxn1       30
# Tnfrsf13c   32
# Cd86        32
# Ly75        32
# Fcer2a      33
# Sdc1        33
# Ctsl        33
# Klrb1c      33
# Cd74        33
# Axl         33
# Ly6a        35
# Sdc4        35
# H2-Aa       35
# H2-Eb1      35
# Flot1       36
# Sema6d      36
# Flt3        36
# Itgb1       37
# Vwf         37
# Treml1      37
# Itgb3       37
# Cd38        37
# Cd9         37
# Spn         38
# Thy1        39
# Lilrb4a     43
# Itgb2       43
# Thbs1       43
# Ly6d        43
# Hnrnpu      44
# Gp5         45
# Itga2b      45
# Slc11a1     46
# Ighd        46
# Il7r        46
# Gfra1       46
# Adam8       46
# Itgb7       47
# Icos        47
# Itga4       48
# S100a10     48
# Mrc1        50
# Cd5l        50
# Cd33        50
# Adgre4      50
# Ccr9        50
# Il12a       50
# Cd24a       50
# Pdgfc       50
# Pirb        50
# Cd22        50
# Dpp4        51
# Msn         51
# Cd44        51
# Cd63        52
# Il6st       53
# Ctss        53
# Sulf2       53
# Fcgr1       53
# Vamp8       54
# Lyn         55
# Rala        55
# Itga6       56
# Stx4a       56
# Lrp6        60
# Eng         60
# H2-Q7       61
# Adam10      63
# Abcg2       63
# Picalm      66
# Slc1a3      68
# Cd36        68
# Adgre5      68
# Heg1        69
# Clic4       69
# Cd55        70
# Vamp5       70
# Tgfbr3      70
# Tspan32     72
# F2r         72
# Irak1       73
# Cd47        74
# H2-DMa      74
# Cd34        75
# Notch1      75
# Tnfrsf13b   76
# Itgam       79
# Slco3a1     80
# Arpc2       80
# Slc38a1     80
# Pecam1      80
# Slc3a2      80
# Btla        81
# Bst2        81
# Il6ra       82
# Lrp1        82
# Sort1       82
# Ramp1       83
# Hcst        83
# Cxcr4       83
# Cd53        84
# Trf         84
# Nfam1       84
# H13         84
# Plaur       84
# Vsir        84
# Nrros       85
# Sirpa       85
# Cd93        86
# Tnfrsf1a    86
# Cd79b       86
# Ly9         86
# Lgals1      87
# Lman2       89
# Pdia3       91
# Erp44       91
# Clec5a      92
# Ly6c2       92
# Adgre1      92
# Siglece     92
# Elane       93
# Fcgr4       93
# Fcgr3       93
# Gsr         93
# Atp6ap2     93
# Arsb        93
# Cd48        94
# Itgal       94
# Cxcr2       94
# Clec12a     95
# Fcgr2b      95
# Tyrobp      95
# Calr        95
# Erp29       95
# Pdia4       95
# P4hb        95
# Anxa1       96
# Ctsb        96
# App         96
# Tcn2        96
# Anxa2       97
# Fcer1g      97
# Sell        97
# Lbp         98
# Bace1       98
# Rnpep       98
# Ckap4       98
# Hfe         99
# Sorl1       99
# Hspa5       99
# Aamp       103
# Pdgfrb     103
# Vcam1      104
# Prom1      104
# Ncam1      105
# C3         105
# Ceacam1    105
# Neu1       105
# Cd163      106
# Clec2i     106
# Cd69       106
# Klrb1f     108
# Cx3cr1     108
# Ccr2       108
# Csf1r      108
# Klrk1      108
# Nrp1       108
# Lpl        109
# Klrd1      109
# Ighm       109
# C1qbp      113
# Phb2       113
# Lgals3     117
# Got2       118
# Lamp1      119
# Rer1       120
# Usp14      120
# Ide        122
# Eno1       123
# Mif        125
# Hsp90ab1   126
# Pebp1      127
# Hmgb1      131
# Hspa8      133
# Nptn       135
# Tfrc       139
# Hsp90aa1   140
# Ncl        142
# Aimp1      142
# Hspd1      144
# Hnrnpm     149
# C5ar1      153
# Cd79a      153
# Ltf        153
# Sptb       155
# Tspan8     155
# Smim1      155
# Tspan33    156
# Epor       156
# Stx2       156
# Gypa       156
# Atp1b2     156
# Tgfb1      163
# Cd19       163
# Slamf7     163
# Itgb2l     166
# Ly6g       166
# Ms4a1      167
# Il1rl1     167
# Ccr1       169
# Fcer1a     169
# Cdh1       169
# Cd200r3    169
# Ms4a2      169

# %%
fig = plt.figure(constrained_layout=True, figsize=(15,15))
ax = fig.add_gridspec(60, 60)
ax1 = fig.add_subplot(ax[1:60, 0])
ax2 = fig.add_subplot(ax[0, 1:])
ax3 = fig.add_subplot(ax[1:60, 1:])


# Cluster color bar
plot_cluster_bars = sm_gene_clusters[[1]].copy()
unique_clusters = plot_cluster_bars[1].unique()
map_cluster_to_order = pd.Series(\
    list(range(len(unique_clusters))), 
    index=unique_clusters).to_dict()
plot_cluster_bars[1] = plot_cluster_bars[1].replace(\
    map_cluster_to_order)
plot_cluster_bars.columns.name = None




rowClusters = sns.heatmap(plot_cluster_bars.astype(np.float32),
                        cmap="cubehelix",
                        yticklabels=False,
                        xticklabels=False,
                        cbar=False,
                        ax=ax1)

colClusters = sns.heatmap(seqlets_to_sm_genes[["gene_cluster"]].T.astype(np.float32),
                        cmap="tab20",
                        yticklabels=False,
                        xticklabels=False,
                        cbar=False,
                        ax=ax2)

heat1 = sns.heatmap(cor_df, 
    vmin=-1, 
    vmax=1, 
    cmap="coolwarm",
    xticklabels=False,
    yticklabels=False,
    cbar=False,
    ax=ax3,
    rasterized=True)


plt.savefig("output/FINAL_FIGURES_DIR/gene_seqlet_corr_surface_protein_genes.pdf")

# %%
sm_gene_clusters = sm_gene_clusters.reset_index()
sm_gene_clusters.columns = ["gene", "cluster"]

# %%
### Save the Gene clusters used and Seqlet clusters used to make subplots later
# Marker genes - vertical axis
sm_gene_clusters.to_csv(\
    "output/chrombpnet/modisco_merged_results/fold_0/redo_extract_seqlets/WITH_ALL_GENES/"\
    "seqlet_to_gene_expression_correlation_surface_marker_genes.csv",
    header=True, index=False)

# Seqlets - horizontal axis
seqlets_to_sm_genes.to_csv(\
    "output/chrombpnet/modisco_merged_results/fold_0/redo_extract_seqlets/WITH_ALL_GENES/"\
    "seqlet_to_gene_expression_correlation_seqlets_overlapping_surface_marker_genes.csv",
    header=True, index=False)
