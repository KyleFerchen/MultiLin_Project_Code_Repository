# %%
import os
import pandas as pd
import numpy as np
import scanpy as sc
import re
from gimmemotifs.motif import Motif,read_motifs

from pyInfinityFlow.InfinityFlow_Utilities import pearson_corr_df_to_df

import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Arial"
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42

os.chdir("/media/kyle_storage/kyle_ferchen/grimes_lab_main/analysis/"\
    "2023_06_12_tea_seq_atac_processing/")
# Out:
# INFO:matplotlib.font_manager:Failed to extract font properties from /usr/share/fonts/truetype/noto/NotoColorEmoji.ttf: In FT2Font: Can not load face (unknown file format; error code 0x2)

# %%
# Read in the CITE-seq RNA counts
path_cite_data = "/media/kyle_storage/kyle_ferchen/grimes_lab_main/data/"\
    "2021_11_mouse_optimized_cite_seq/processed_files/"

adata_cite = sc.read(os.path.join(\
    path_cite_data, 
    "cite_seq_adata_rna_combined.h5ad"))
print("Computing CPTT normalized scRNA-seq from CITE-seq...")
adata_cite.X = np.log2((10000 * (adata_cite.X.T / \
    adata_cite.X.sum(axis=1).T).T) + 1)
cite_cell_anno = pd.read_csv(os.path.join(\
    path_cite_data, 
    "cite_seq_cell_annotations.csv"))
cite_cell_anno.index = cite_cell_anno["Cell_Barcode"].values

# Make pseudobulk RNA counts from cite clusters
print("Computing RNA centroids...")
shared_cells_cite = np.intersect1d(cite_cell_anno.index.values, 
    adata_cite.obs.index.values)
cite_cell_anno = cite_cell_anno.loc[shared_cells_cite]
cite_rna = {}
for tmp_cluster in cite_cell_anno["sctri_cite"].unique():
    print("\t{}...".format(tmp_cluster))
    tmp_barcodes = cite_cell_anno.loc[\
        cite_cell_anno["sctri_cite"] == tmp_cluster].index.values
    cite_rna[tmp_cluster] = pd.Series(np.asarray(\
            adata_cite[tmp_barcodes].X.mean(axis=0)).reshape(-1),
            index=adata_cite.var.index.values)

cite_rna = pd.DataFrame(cite_rna)
cite_rna = cite_rna.drop("Unknown", axis=1)
map_r7_names = pd.read_csv(os.path.join(\
    path_cite_data, 
    "map_r7-v1_to_r7-v2_names.csv"))
map_r7_names_v1_to_v2 = pd.Series(\
    map_r7_names["R7_V2"].values,
    index = map_r7_names["R7_V1"].values)

cite_rna = cite_rna.rename(map_r7_names_v1_to_v2, axis=1)
cite_rna.columns = [i.replace("-", "_") for i in cite_rna.columns.values]
# Out:
# Computing CPTT normalized scRNA-seq from CITE-seq...
# Computing RNA centroids...
# 	ERP4--Ex...
# 	MultiLin-2_ML-c9--RNA...
# 	ERP2_Kit-c14--RNA...
# 	ERP2--Ex...
# 	Ebf1+_proB_CD127-c2--RNA...
# 	proNeu-1_1-4--ADT...
# 	Unknown...
# 	preNeu-2_1-8--ADT...
# 	cMoP_ML-c15--RNA...
# 	immNeu_Kit-c3--RNA...
# 	MP--Ex...
# 	proNeu-2_Kit-c4--RNA...
# 	Ebf1+_proB--Ex...
# 	ML_ERP1_ML-c4--RNA...
# 	MDP--Ex...
# 	preNeu-3_Kit-c2--RNA...
# 	ERP4_Kit-c13--RNA...
# 	preNeu-3_2-3--ADT...
# 	immNeu_2-5--ADT...
# 	preNeu-1_Kit-c5--RNA...
    "cisbp2/Mus_musculus_2020_06_01_11_53_pm/"
path_pwms = os.path.join(path_cisbp, "pwms_all_motifs/")
path_cisbp_anno = os.path.join(path_cisbp, "TF_Information_all_motifs.txt")

cisbp_anno = pd.read_table(path_cisbp_anno)
cisbp_anno = cisbp_anno.loc[cisbp_anno["Motif_ID"] != "."]

cisbp2_motifs = read_motifs(os.path.join(path_cisbp, "mouse_cisbp2_all_motif_ids_ppm_format.motif"))
cisbp2_names = np.array([str(x) for x in cisbp2_motifs])

# Filter cisbp2 annotation to only motifs that have a real entry
cisbp_anno = cisbp_anno.loc[cisbp_anno["Motif_ID"].isin(["_".join(i.split("_")[:2]) for i in cisbp2_names])]

map_id_to_tf = cisbp_anno[["Motif_ID", "TF_Name"]].drop_duplicates()

# %%
path_to_cisbp_correlations = "output/chrombpnet/modisco_merged_results/fold_0/"\
    "correlate_modisco_to_cisbp2_motifs/"

corr_files = [i for i in os.listdir(path_to_cisbp_correlations) if \
    i.endswith("csv") and not i.startswith(".")]

modisco_pattern_re = re.compile(r'(\w+__pattern_[0-9]+)_\w+.csv')

corr_files = pd.Series(\
    corr_files, 
    index=[modisco_pattern_re.findall(i)[0] for i in corr_files])

pat_corrs = {}
for tmp_pat in corr_files.index.values:
    pat_corrs[tmp_pat] = pd.read_csv(os.path.join(\
        path_to_cisbp_correlations,
        corr_files[tmp_pat]))

for tmp_pat in pat_corrs:
    pat_corrs[tmp_pat].loc[:,"motif_pattern"] = [i.split("_")[-1] \
        for i in pat_corrs[tmp_pat]["motif"].values]
    pat_corrs[tmp_pat].loc[:,"motif"] = ["_".join(i.split("_")[:-1]) \
        for i in pat_corrs[tmp_pat]["motif"].values]
    pat_corrs[tmp_pat] = pat_corrs[tmp_pat].set_index("motif")

# %%
pat_corrs["BMCP__pattern_25"].sort_values(by="r", ascending=False)
# Out:
#                                                      pattern  offset strand  \
# motif
# M08127_2.00  BMCP__pattern_25_nnnnnGTnCTTATCTGnnnnnnnnnnnnnn      13      -
# M09123_2.00  BMCP__pattern_25_nnnnnGTnCTTATCTGnnnnnnnnnnnnnn      13      -
# M09121_2.00  BMCP__pattern_25_nnnnnGTnCTTATCTGnnnnnnnnnnnnnn      13      -
# M08126_2.00  BMCP__pattern_25_nnnnnGTnCTTATCTGnnnnnnnnnnnnnn      12      -
# M09120_2.00  BMCP__pattern_25_nnnnnGTnCTTATCTGnnnnnnnnnnnnnn      13      -
# ...                                                      ...     ...    ...
# M02935_2.00  BMCP__pattern_25_nnnnnGTnCTTATCTGnnnnnnnnnnnnnn      17      +
# M00139_2.00  BMCP__pattern_25_nnnnnGTnCTTATCTGnnnnnnnnnnnnnn      19      +
# M08978_2.00  BMCP__pattern_25_nnnnnGTnCTTATCTGnnnnnnnnnnnnnn      10      +
# M00143_2.00  BMCP__pattern_25_nnnnnGTnCTTATCTGnnnnnnnnnnnnnn      18      +
# M00784_2.00  BMCP__pattern_25_nnnnnGTnCTTATCTGnnnnnnnnnnnnnn      16      +
#
#                     r         motif_pattern
# motif
# M08127_2.00  0.937167           rnAGATAAGrA
# M09123_2.00  0.930855            nnAGATAAGA
# M09121_2.00  0.928374           nsAGATAAGrn
# M08126_2.00  0.925646           nnsAGATAAGr
# M09120_2.00  0.915643            nnAGATAAGn
# ...               ...                   ...
# M02935_2.00  0.095082            nCCCCCCCAC
# M00139_2.00  0.093277            CnwCCCCCmn
# M08978_2.00  0.091463  nnCnnGCCCCGCCCCCnnnn
# M00143_2.00  0.089067            nCCCCCCnnn
# M00784_2.00  0.083585            CCCCCCCnnn
#
# [1361 rows x 5 columns]

# %%
unique_motifs = []
for tmp_pat in pat_corrs:
    unique_motifs += list(pat_corrs[tmp_pat].index.values)

unique_motifs = np.unique(unique_motifs)
mo_similarities = pd.DataFrame(0, index=list(pat_corrs.keys()), 
    columns=unique_motifs)
for tmp_pat in pat_corrs:
    mo_similarities.loc[\
        tmp_pat, 
        pat_corrs[tmp_pat].index.values] = pat_corrs[tmp_pat]["r"].values
    
mo_similarities
# Out:
#                             M00111_2.00  M00112_2.00  M00113_2.00  \
# HSCP_HPC_Cenpf__pattern_25     0.202201     0.240010     0.211908
# LT_HSC_Mllt3__pattern_8        0.413618     0.382552     0.361313
# MPP5_Flt3__pattern_1           0.497018     0.434836     0.437839
# BMCP__pattern_0                0.483937     0.384676     0.436416
# BMCP__pattern_10               0.273003     0.279414     0.300172
# ...                                 ...          ...          ...
# HSCP_HPC_Cenpf__pattern_20     0.341943     0.322229     0.332862
# HSCP_HPC_Cenpf__pattern_21     0.288247     0.334039     0.281859
# HSCP_HPC_Cenpf__pattern_22     0.549329     0.612334     0.555310
# HSCP_HPC_Cenpf__pattern_23     0.306296     0.267893     0.258015
# HSCP_HPC_Cenpf__pattern_24     0.292698     0.318021     0.275278
#
#                             M00114_2.00  M00115_2.00  M00116_2.00  \
# HSCP_HPC_Cenpf__pattern_25     0.257100     0.258435     0.185724
# LT_HSC_Mllt3__pattern_8        0.392718     0.077250     0.152473
# MPP5_Flt3__pattern_1           0.434691     0.164640     0.092760
# BMCP__pattern_0                0.427572     0.047236     0.086255
# BMCP__pattern_10               0.268997     0.259189     0.185422
# ...                                 ...          ...          ...
# HSCP_HPC_Cenpf__pattern_20     0.376382     0.157247     0.163326
# HSCP_HPC_Cenpf__pattern_21     0.309338     0.317346     0.175181
# HSCP_HPC_Cenpf__pattern_22     0.599159     0.325205     0.169126
# HSCP_HPC_Cenpf__pattern_23     0.282877     0.231764     0.409715
# HSCP_HPC_Cenpf__pattern_24     0.282655     0.322089     0.244093
#
#                             M00117_2.00  M00118_2.00  M00119_2.00  \
# HSCP_HPC_Cenpf__pattern_25     0.291062     0.311243     0.226841
# LT_HSC_Mllt3__pattern_8        0.322053     0.353005     0.282305
# MPP5_Flt3__pattern_1           0.417630     0.494317     0.322522
# BMCP__pattern_0                0.166355     0.294221     0.280555
# BMCP__pattern_10               0.643987     0.699773     0.900607
# ...                                 ...          ...          ...
# HSCP_HPC_Cenpf__pattern_20     0.333682     0.318763     0.217711
# HSCP_HPC_Cenpf__pattern_21     0.187095     0.163493
# HSCP_HPC_Cenpf__pattern_22     0.228951     0.227655
# HSCP_HPC_Cenpf__pattern_23     0.202582     0.273310
# HSCP_HPC_Cenpf__pattern_24     0.235401     0.299280
#
# [1030 rows x 1361 columns]

# %% [markdown]
# Check Irf8

# %%
map_id_to_tf.loc[map_id_to_tf["TF_Name"] == "Irf8"]
# Out:
#           Motif_ID TF_Name
# 10795  M09246_2.00    Irf8

# %%
mo_similarities["M09246_2.00"].sort_values()
# Out:
# ML_cell_cycle__pattern_14       0.054666
# ERP2__pattern_14                0.060635
# HSCP_ERP1__pattern_12           0.061567
# IG2_MP__pattern_11              0.064072
# HSCP_HPC_Cenpf__pattern_15      0.068479
#                                   ...
# MDP_Irf8__pattern_14            0.911989
# MDP_Cpa3__pattern_17            0.937892
# CD127_MP__pattern_9             0.976982
# MDP_Irf8__pattern_12            0.977764
# MultiLin_2_F13a1__pattern_11    0.978887
# Name: M09246_2.00, Length: 1030, dtype: float64

# %% [markdown]
# Pu.1

# %%
map_id_to_tf.loc[map_id_to_tf["TF_Name"] == "Spi1"]
# Out:
#          Motif_ID TF_Name
# 2248  M00155_2.00    Spi1
# 2249  M01475_2.00    Spi1
# 2250  M08027_2.00    Spi1
# 2251  M09065_2.00    Spi1
# 2252  M09538_2.00    Spi1

# %%
mo_similarities["M08027_2.00"].sort_values()
# Out:
# HSCP_ERP1__pattern_12          0.074018
# MPP4_Nkx2_3__pattern_18        0.083438
# MDP_Irf8__pattern_17           0.086101
# ERP2__pattern_14               0.086308
# pre_MultiLin_2__pattern_15     0.090617
#                                  ...
# MPP4_Nkx2_3__pattern_1         0.960101
# BMCP__pattern_2                0.964984
# MDP_Cpa3__pattern_0            0.966150
# CD127_MP__pattern_0            0.967661
# MultiLin_2_F13a1__pattern_0    0.969131
# Name: M08027_2.00, Length: 1030, dtype: float64

# %% [markdown]
# Myc

# %%
map_id_to_tf.loc[map_id_to_tf["TF_Name"] == "Myc"]
# Out:
#         Motif_ID TF_Name
# 236  M08751_2.00     Myc
# 237  M09467_2.00     Myc

# %%
mo_similarities["M08751_2.00"].sort_values()
# Out:
# ST_HSC__pattern_24               -0.008677
# HSCP_HPC_Hist1h2af__pattern_20   -0.005072
# pre_MultiLin_1__pattern_13       -0.002683
# LT_HSC_Mllt3__pattern_18         -0.000109
# MPP5_Egr1__pattern_16             0.001345
#                                     ...
# IG2_proNeu1__pattern_10           0.766721
# CD127_MP__pattern_12              0.767995
# eHSC_Pcna__pattern_11             0.772246
# LT_HSC_Mllt3__pattern_11          0.773401
# BMCP__pattern_10                  0.774147
# Name: M08751_2.00, Length: 1030, dtype: float64

# %%
pat_corrs["BMCP__pattern_10"].sort_values(by="r", ascending=False)
# Out:
#                                                      pattern  offset strand  \
# motif
# M08756_2.00  BMCP__pattern_10_nnnnnnnnCACGTGACnnnnnnnnnnnnnn      12      -
# M08753_2.00  BMCP__pattern_10_nnnnnnnnCACGTGACnnnnnnnnnnnnnn      13      +
# M08777_2.00  BMCP__pattern_10_nnnnnnnnCACGTGACnnnnnnnnnnnnnn      12      -
# M01751_2.00  BMCP__pattern_10_nnnnnnnnCACGTGACnnnnnnnnnnnnnn      13      +
# M05833_2.00  BMCP__pattern_10_nnnnnnnnCACGTGACnnnnnnnnnnnnnn      14      +
# ...                                                      ...     ...    ...
# M08277_2.00  BMCP__pattern_10_nnnnnnnnCACGTGACnnnnnnnnnnnnnn      20      -
# M09255_2.00  BMCP__pattern_10_nnnnnnnnCACGTGACnnnnnnnnnnnnnn      13      +
# M08325_2.00  BMCP__pattern_10_nnnnnnnnCACGTGACnnnnnnnnnnnnnn      20      -
# M09252_2.00  BMCP__pattern_10_nnnnnnnnCACGTGACnnnnnnnnnnnnnn      14      +
# M09253_2.00  BMCP__pattern_10_nnnnnnnnCACGTGACnnnnnnnnnnnnnn      12      +
#
#                     r          motif_pattern
# motif
# M08756_2.00  0.961201          nnGTCACGTGrCs
# M08753_2.00  0.957774              CACGTGACy
# M08777_2.00  0.957249    nGGTCACGTGnnsnnnnnn
# M01751_2.00  0.951297             nCACGTGACn
# M05833_2.00  0.946457               CACGTGAy
# ...               ...                    ...
# M08277_2.00  0.042748  TTTTyyTnTTTTTTynyTTyn
# M09255_2.00  0.040652         nnCyAAAAATAGmn
# M08325_2.00  0.035841              TTTTTTTTT
# M09252_2.00  0.031166         nkCTAAAAATAGmn
# M09253_2.00  0.030444        nkCyAAAAATAGmnn
#
# [1361 rows x 5 columns]

# %%
pat_corrs["BMCP__pattern_10"].loc["M08751_2.00"]
# Out:
# pattern          BMCP__pattern_10_nnnnnnnnCACGTGACnnnnnnnnnnnnnn
# offset                                                        13
# strand                                                         +
# r                                                       0.774147
# motif_pattern                                       GnsCACGTGGnn
# Name: M08751_2.00, dtype: object

# %% [markdown]
# Gfi1

# %%
map_id_to_tf.loc[map_id_to_tf["TF_Name"] == "Gfi1"]
# Out:
#         Motif_ID TF_Name
# 871  M08984_2.00    Gfi1

# %%
mo_similarities["M08984_2.00"].sort_values()
# Out:
# MPP5_Flt3__pattern_23             0.074109
# HSCP_HPC_Hist1h2af__pattern_19    0.079016
# IG2_MP__pattern_11                0.084049
# MDP_Cpa3__pattern_8               0.087545
# ML_cell_cycle__pattern_14         0.088592
#                                     ...
# MPP5_Egr1__pattern_5              0.622141
# ERP2__pattern_3                   0.623317
# MPP4_Hlf__pattern_9               0.628484
# LT_HSC_Mllt3__pattern_3           0.630087
# ERP1__pattern_7                   0.631999
# Name: M08984_2.00, Length: 1030, dtype: float64

# %%
pat_corrs["ERP1__pattern_7"].loc["M08984_2.00"]
# Out:
# pattern          ERP1__pattern_7_nnnnnnnnnnnyTGTGGTTTnnnnnnnnnn
# offset                                                       10
# strand                                                        -
# r                                                      0.631999
# motif_pattern                                        AAATCAswGC
# Name: M08984_2.00, dtype: object

# %%
gene_to_seqlets = pd.read_feather("output/chrombpnet/modisco_merged_results/"\
    "fold_0/redo_extract_seqlets/correlate_seqlets_to_gene_expression/"\
    "seqlet_to_gene_conns_filtered_to_marker_genes_n25.fea")
gene_to_seqlets = gene_to_seqlets.loc[\
    ~gene_to_seqlets["pattern"].str.contains("__neg_pattern_")]
gene_to_seqlets["pattern"] = gene_to_seqlets["pattern"].str.replace(\
    "__pos_pattern_", "__pattern_")
gene_to_seqlets
# Out:
#           Gene  seqlet_idx         r     index   chr      start        end  \
# 0        Ube2w         999  0.431932       999  chr1   14995472   14995502
# 1        Ube2w        1010  0.807602      1010  chr1   15176376   15176406
# 2        Ube2w        1011  0.803144      1011  chr1   15176378   15176408
# 3        Ube2w        1012  0.798769      1012  chr1   15176380   15176410
# 4        Ube2w        1013  0.490000      1013  chr1   15176388   15176418
# ...        ...         ...       ...       ...   ...        ...        ...
# 1365889  Prdx4    16096769  0.454015  16096769  chrX  155338453  155338483
# 1365890  Prdx4    16096770  0.404356  16096770  chrX  155338455  155338485
# 1365891  Prdx4    16096771  0.406877  16096771  chrX  155338461  155338491
# 1365892  Prdx4    16096772  0.488150  16096772  chrX  155338462  155338492
# 1365893  Prdx4    16096773  0.430923  16096773  chrX  155338463  155338493
#
#                              peak      score  pos strand             pattern  \
# 0          chr1:14995049-14996049  10.999075  424      -     BMCP__pattern_2
# 1          chr1:15176006-15177006   6.002641  371      +    BMCP__pattern_36
# 2          chr1:15176006-15177006   9.193361  373      -     BMCP__pattern_3
# 3          chr1:15176006-15177006   5.916835  375      -    BMCP__pattern_32
# 4          chr1:15176006-15177006   9.033985  383      -     BMCP__pattern_7
# ...                           ...        ...  ...    ...                 ...
# 1365889  chrX:155337965-155338965   8.410910  489      +   ST_HSC__pattern_2
# 1365890  chrX:155337965-155338965  13.204884  491      -  ST_HSC__pattern_21
# 1365891  chrX:155337965-155338965  13.178372  497      +  ST_HSC__pattern_21
# 1365892  chrX:155337965-155338965   8.482800  498      +  ST_HSC__pattern_17
# 1365893  chrX:155337965-155338965   7.177069  499      +  ST_HSC__pattern_14
#
#          in_modisco                  seq_name  dp_score Cisbp2_TF  \
# 0             False    chr1:14995472-14995502  0.207860      Spi1
# 1             False    chr1:15176376-15176406  0.502043     Cebpg
# 2              True    chr1:15176378-15176408  0.545012     Cebpa
# 3             False    chr1:15176380-15176410  0.437181     Cebpa
# 4             False    chr1:15176388-15176418  0.423640     Runx1
# ...             ...                       ...       ...       ...
# 1365889       False  chrX:155338453-155338483  0.201752       Sp3
# 1365890       False  chrX:155338455-155338485  0.582122    Zbtb33
# 1365891       False  chrX:155338461-155338491  0.573688    Zbtb33
# 1365892       False  chrX:155338462-155338492  0.367858    Zfp523
# 1365893       False  chrX:155338463-155338493  0.418183      Tfeb
#
#         Cisbp2_TF_Family
# 0                    Ets
# 1                   bZIP
# 2                   bZIP
# 3                   bZIP
# 4                   Runt
# ...                  ...
# 1365889          C2H2 ZF
# 1365890          C2H2 ZF
# 1365891          C2H2 ZF
# 1365892          C2H2 ZF
# 1365893             bHLH
#
# [1360709 rows x 17 columns]

# %%
# path_to_gene_to_seqlet_anno = "output/chrombpnet/modisco_merged_results/"\
#     "fold_0/redo_extract_seqlets/"\
#     "gene_to_seqlet_connections_within_tads_Cisbp2_annotations.csv"

# gene_to_seqlets = pd.read_csv(path_to_gene_to_seqlet_anno)
# gene_to_seqlets = gene_to_seqlets.loc[\
#     ~gene_to_seqlets["pattern"].str.contains("__neg_pattern_")]
# gene_to_seqlets["pattern"] = gene_to_seqlets["pattern"].str.replace(\
#     "__pos_pattern_", "__pattern_")
# gene_to_seqlets

# %%
### Build TF to gene correlation matrix (pseudobulk CITE-seq CPTT)
## Only use clusters with modisco results
clusters_to_use = np.unique([i.split("__")[0] for i in list(pat_corrs.keys())])

shared_tfs = np.intersect1d(\
    map_id_to_tf["TF_Name"].unique(), 
    cite_rna.index.values)

tf2gene = pearson_corr_df_to_df(\
    cite_rna.loc[shared_tfs, clusters_to_use].T,
    cite_rna.loc[gene_to_seqlets["Gene"].unique(), clusters_to_use].T).dropna()

tf2gene
# Out:
#                Ube2w  Crispld1      Mcm3       Dst    Rnf149     Il1r1  \
# AC168977.1 -0.193185  0.315213 -0.008454  0.312728  0.159270  0.516580
# Ahctf1     -0.650111 -0.044839  0.034612 -0.024560 -0.398138 -0.172991
# Ahr        -0.097477  0.818891 -0.497163  0.872236  0.310685  0.377527
# Aire       -0.248137  0.846966 -0.717430  0.759419  0.388685  0.582389
# Alx1       -0.137000  0.061733 -0.159770  0.018128 -0.261601  0.075535
# ...              ...       ...       ...       ...       ...       ...
# Zscan20    -0.207697  0.852965 -0.664307  0.845913  0.316484  0.502062
# Zscan26    -0.124648  0.907696 -0.786915  0.930708  0.379809  0.390734
# Zscan29     0.114868  0.656484 -0.702329  0.683454  0.180597  0.133504
# Zscan4d     0.191993 -0.108852 -0.109522 -0.121262  0.127829  0.005741
# Zzz3       -0.733357  0.396891 -0.140646  0.451538 -0.299715  0.073442
#
#               Il1rl1     Gm973      Idh1     Acadl  ...     Gria3       Bgn  \
# AC168977.1 -0.360217  0.116773 -0.335185 -0.284729  ... -0.218522  0.193926
# Ahctf1      0.396183 -0.068390 -0.531872  0.378324  ... -0.474163  0.048396
# Ahr        -0.373789  0.908719 -0.276114 -0.649331  ... -0.131852  0.821058
# Aire       -0.302047  0.617476 -0.283178 -0.585586  ... -0.183318  0.594610
# Alx1        0.094295  0.010506 -0.093776  0.050735  ... -0.110423  0.072619
# ...              ...       ...       ...       ...  ...       ...       ...
# Zscan20    -0.437200  0.708045 -0.297726 -0.667199  ... -0.135971  0.772622
# Zscan26    -0.290537  0.919952 -0.208815 -0.680915  ... -0.070266  0.833168
# Zscan29    -0.194870  0.655993  0.080600 -0.520130  ... -0.054218  0.577103
# Zscan4d    -0.017532 -0.104682  0.131251 -0.008955  ...  0.098490 -0.116394
# Zzz3        0.096674  0.226475 -0.678844  0.153819  ... -0.653083  0.513116
#
#                Pola1    Maged1  F630028O10Rik      Dlg3       Ogt    Tspan6  \
# AC168977.1  0.027786  0.285680      -0.311218  0.400731  0.184981  0.561066
# Ahctf1      0.180060 -0.078183      -0.469761  0.148153 -0.167159  0.207479
# Ahr        -0.483357  0.923598      -0.351779  0.331204  0.713398  0.505114
# Aire       -0.627083  0.705915      -0.380456  0.237666  0.748480  0.591179
# Alx1        0.011939 -0.038177      -0.111148  0.114383 -0.016737  0.142182
# ...              ...       ...            ...       ...       ...       ...
# Zscan20    -0.517071  0.777572      -0.394345  0.429235  0.707177  0.643539
# Zscan26    -0.717706  0.906550      -0.332398  0.215372  0.819926  0.476693
# Zscan29    -0.628954  0.635729       0.005846  0.152926  0.598976  0.232314
# Zscan4d     0.014860 -0.119084       0.083230 -0.101966 -0.026273 -0.101074
# Zzz3       -0.000310  0.348036      -0.694479  0.741069  0.328315  0.703959
#
#              Gprasp2     Prdx4
# AC168977.1  0.295366  0.256068
# Ahctf1     -0.027726  0.598227
# Ahr         0.892425 -0.022740
# Aire        0.705487 -0.058928
# Alx1        0.029882  0.231045
# ...              ...       ...
# Zscan20     0.823552  0.109566
# Zscan26     0.907875 -0.124793
# Zscan29     0.685331 -0.349913
# Zscan4d    -0.132362 -0.073572
# Zzz3        0.439732  0.619075
#
# [727 rows x 732 columns]

# %%
mo_sim_threshold = 0.75
tf2gene_threshold = 0.4

conn_results = {}
for tmp_gene in gene_to_seqlets["Gene"].unique():
    print(f"Working on {tmp_gene}...")
    # Filter to seqlet connections for the given gene
    seg_gene2seqlets = gene_to_seqlets.loc[gene_to_seqlets["Gene"] == tmp_gene]
    # Pull out the unique patterns connected to that gene
    seg_pats = seg_gene2seqlets["pattern"].unique()
    # Pull out the motifs that match the patterns above given threshold
    seg_mo_sims = mo_similarities.loc[seg_pats]
    seg_mo = seg_mo_sims.columns.values[seg_mo_sims.max(axis=0) > mo_sim_threshold]

    # Pull out the TFs with a PWM that match that pattern
    seg_tf = map_id_to_tf.loc[\
        map_id_to_tf["Motif_ID"].isin(seg_mo), "TF_Name"].unique()
    seg_tf = np.intersect1d(seg_tf, tf2gene.index.values)

    # Identify the TFs that correlate to the gene
    seg_tf2gene = tf2gene.loc[seg_tf, tmp_gene]
    seg_tf2gene = seg_tf2gene[seg_tf2gene > tf2gene_threshold]
    seg_tf = seg_tf2gene.index.values

    # Pull out the IDs for those TFs
    seg_id2tf = map_id_to_tf.loc[map_id_to_tf["TF_Name"].isin(seg_tf)]
    seg_id2tf = seg_id2tf.loc[seg_id2tf["Motif_ID"].isin(seg_mo)]

    n_con = len(seg_id2tf['TF_Name'].unique())
    print(f"\tFound {n_con} TF-gene connections...")
    if n_con > 0:
        # Get the motif to TF names
        seg_mo_sims = seg_mo_sims[seg_id2tf["Motif_ID"].unique()]
        seg_mo_sims = seg_mo_sims.loc[seg_mo_sims.max(axis=1) > mo_sim_threshold]
        seg_mo_sims = seg_mo_sims.unstack().reset_index()
        seg_mo_sims.columns = ["Motif", "Pattern", "Motif_r"]
        seg_mo_sims = seg_mo_sims.loc[seg_mo_sims["Motif_r"] > mo_sim_threshold]



        new_conns = []
        for tmp_tf in seg_id2tf["TF_Name"].unique():
            # Reselect motif ids that map to the indicated TF
            tmp_mo_ids = seg_id2tf.loc[\
                seg_id2tf["TF_Name"] == tmp_tf, "Motif_ID"].values
            # Reselect patterns that map to those motif ids above
            tmp_pats = seg_mo_sims.loc[\
                seg_mo_sims["Motif"].isin(tmp_mo_ids), "Pattern"].unique()
            # Select the connections that match those patterns
            tmp_new_conns = seg_gene2seqlets.loc[\
                seg_gene2seqlets["pattern"].isin(tmp_pats)].copy()
            # Label the connection with the TF name
            tmp_new_conns["TF_CON"] = tmp_tf
            new_conns.append(tmp_new_conns)

        new_conns = pd.concat(new_conns)

    else:
        seg_mo_sims = None
        new_conns = None

    conn_results[tmp_gene] = {\
        "new_conns": new_conns,
        "seg_mo_sims": seg_mo_sims,
        "seg_id2tf": seg_id2tf,
        "seg_tf2gene": seg_tf2gene}
# Out:
# Working on Ube2w...
# 	Found 14 TF-gene connections...
# Working on Crispld1...
# 	Found 55 TF-gene connections...
# Working on Mcm3...
# 	Found 1 TF-gene connections...
# Working on Dst...
# 	Found 83 TF-gene connections...
# Working on Rnf149...
# 	Found 11 TF-gene connections...
# Working on Il1r1...
# 	Found 39 TF-gene connections...
# Working on Il1rl1...
# 	Found 9 TF-gene connections...
# Working on Gm973...
# 	Found 103 TF-gene connections...
# Working on Idh1...
# 	Found 6 TF-gene connections...
# Working on Acadl...
# 	Found 8 TF-gene connections...
# Working on Ikzf2...
# 	Found 13 TF-gene connections...
# Working on Cxcr2...
# 	Found 8 TF-gene connections...
# Working on Serpine2...
# 	Found 3 TF-gene connections...
# Working on Dock10...
# 	Found 5 TF-gene connections...
# Working on Arl4c...
# 	Found 92 TF-gene connections...
# Working on Otos...
# 	Found 80 TF-gene connections...
# Working on Gpc1...
# 	Found 14 TF-gene connections...
# Working on Zcchc2...
# 	Found 78 TF-gene connections...
# Working on Bcl2...
# 	Found 9 TF-gene connections...
# Working on Dbi...
# 	Found 15 TF-gene connections...
# Working on Cd55...
# 	Found 30 TF-gene connections...
# Working on Ctse...
# 	Found 8 TF-gene connections...
# Working on Slc45a3...
# 	Found 8 TF-gene connections...
# Working on Btg2...
# 	Found 87 TF-gene connections...
# Working on Ptpn7...
# 	Found 8 TF-gene connections...
# Working on Aspm...
# 	Found 6 TF-gene connections...
# Working on Uchl5...
# 	Found 9 TF-gene connections...
# Working on Rgs2...
# 	Found 48 TF-gene connections...
# Working on Rgs1...
# 	Found 88 TF-gene connections...
# Working on Fam129a...
# 	Found 2 TF-gene connections...
# Working on Edem3...
# 	Found 2 TF-gene connections...
# Working on Ier5...
# 	Found 107 TF-gene connections...
# Working on 4930523C07Rik...
# 	Found 15 TF-gene connections...
# Working on Prdx6...
# 	Found 5 TF-gene connections...
# Working on Sell...
# 	Found 8 TF-gene connections...
# Working on Pbx1...
# 	Found 43 TF-gene connections...
# Working on Pcp4l1...
# 	Found 106 TF-gene connections...
# Working on Fcer1g...
# 	Found 14 TF-gene connections...
# Working on Cd48...
# 	Found 10 TF-gene connections...
# Working on Slamf1...
# 	Found 33 TF-gene connections...
# Working on Spta1...
# 	Found 6 TF-gene connections...
# Working on Fh1...
# 	Found 35 TF-gene connections...
# Working on Uqcrq...
# 	Found 9 TF-gene connections...
# Working on Gm2a...
# 	Found 18 TF-gene connections...
# Working on Obscn...
# 	Found 77 TF-gene connections...
# Working on Shmt1...
# 	Found 10 TF-gene connections...
# Working on Mmgt2...
# 	Found 47 TF-gene connections...
# Working on Rpl26...
# 	Found 2 TF-gene connections...
# Working on Kdm6b...
# 	Found 100 TF-gene connections...
# Working on Trp53...
# 	Found 15 TF-gene connections...
# Working on Atp1b2...
# 	Found 14 TF-gene connections...
# Working on Cd68...
# 	Found 17 TF-gene connections...
# Working on Nlgn2...
# 	Found 113 TF-gene connections...
# Working on Mgl2...
# 	Found 12 TF-gene connections...
# Working on Txndc17...
# 	Found 17 TF-gene connections...
# Working on Spns2...
# 	Found 110 TF-gene connections...
# Working on Scarf1...
# 	Found 108 TF-gene connections...
# Working on Slfn9...
# 	Found 6 TF-gene connections...
# Working on 1700020L24Rik...
# 	Found 12 TF-gene connections...
# Working on Ccl9...
# 	Found 12 TF-gene connections...
# Working on Ccl3...
# 	Found 66 TF-gene connections...
# Working on Ccl4...
# 	Found 91 TF-gene connections...
# Working on Wfdc17...
# 	Found 27 TF-gene connections...
# Working on Wfdc18...
# 	Found 55 TF-gene connections...
# Working on Prr11...
# 	Found 2 TF-gene connections...
# Working on Hlf...
# 	Found 104 TF-gene connections...
# Working on Lrrc59...
# 	Found 9 TF-gene connections...
# Working on Fam117a...
# 	Found 7 TF-gene connections...
# Working on Gngt2...
# 	Found 102 TF-gene connections...
# Working on Tbkbp1...
# 	Found 104 TF-gene connections...
# Working on Cisd3...
# 	Found 20 TF-gene connections...
# Working on Nt5c3b...
# 	Found 17 TF-gene connections...
# Working on Kif18b...
# 	Found 17 TF-gene connections...
# Working on Itgb3...
# 	Found 9 TF-gene connections...
# Working on Icam2...
# 	Found 5 TF-gene connections...
# Working on Ern1...
# 	Found 18 TF-gene connections...
# Working on Tex2...
# 	Found 14 TF-gene connections...
# Working on Pecam1...
# 	Found 13 TF-gene connections...
# Working on Gm11697...
# 	Found 3 TF-gene connections...
# Working on Grb2...
# 	Found 11 TF-gene connections...
# Working on Smim5...
# 	Found 25 TF-gene connections...
# Working on Sphk1...
# 	Found 13 TF-gene connections...
# Working on Tk1...
# 	Found 15 TF-gene connections...
# Working on Mfsd2b...
# 	Found 19 TF-gene connections...
# Working on Sdc1...
# 	Found 72 TF-gene connections...
# Working on Mycn...
# 	Found 79 TF-gene connections...
# Working on Trib2...
# 	Found 3 TF-gene connections...
# Working on Pdia6...
# 	Found 16 TF-gene connections...
# Working on Klf11...
# 	Found 82 TF-gene connections...
# Working on Rrm2...
# 	Found 8 TF-gene connections...
# Working on Rnf144a...
# 	Found 83 TF-gene connections...
# Working on Rnaseh1...
# 	Found 3 TF-gene connections...
# Working on Scin...
# 	Found 3 TF-gene connections...
# Working on Egln3...
# 	Found 12 TF-gene connections...
# Working on Mis18bp1...
# 	Found 4 TF-gene connections...
# Working on Pole2...
# 	Found 4 TF-gene connections...
# Working on Zbtb25...
# 	Found 1 TF-gene connections...
# Working on Zbtb1...
# 	Found 11 TF-gene connections...
# Working on Tmem229b...
# 	Found 10 TF-gene connections...
# Working on Fos...
# 	Found 83 TF-gene connections...
# Working on Ifi27...
# 	Found 1 TF-gene connections...
# Working on Serpina3g...
# 	Found 71 TF-gene connections...
# Working on Meg3...
# 	Found 25 TF-gene connections...
# Working on Tnfaip2...
# 	Found 12 TF-gene connections...
# Working on Ppp1r13b...
# 	Found 99 TF-gene connections...
# Working on Pld4...
# 	Found 14 TF-gene connections...
# Working on Crip2...
# 	Found 14 TF-gene connections...
# Working on Crip1...
# 	Found 23 TF-gene connections...
# Working on Ighm...
# 	Found 6 TF-gene connections...
# Working on Klf6...
# 	Found 76 TF-gene connections...
# Working on Gpr141...
# 	Found 9 TF-gene connections...
# Working on Zkscan8...
# 	Found 94 TF-gene connections...
# Working on Hist1h2ai...
# 	Found 10 TF-gene connections...
# Working on Hist1h2bm...
# 	Found 12 TF-gene connections...
# Working on Hist1h2ak...
# 	Found 12 TF-gene connections...
# Working on Hist1h2bn...
# 	Found 12 TF-gene connections...
# Working on Hist1h1b...
# 	Found 8 TF-gene connections...
# Working on Hist1h2an...
# 	Found 9 TF-gene connections...
# Working on Hist1h2ap...
# 	Found 11 TF-gene connections...
# Working on Hist1h2bj...
# 	Found 8 TF-gene connections...
# Working on Hist1h4h...
# 	Found 5 TF-gene connections...
# Working on Hist1h2af...
# 	Found 4 TF-gene connections...
# Working on Hist1h3f...
# 	Found 4 TF-gene connections...
# Working on Hist1h1d...
# 	Found 5 TF-gene connections...
# Working on Hist1h3e...
# 	Found 3 TF-gene connections...
# Working on Hist1h2ae...
# 	Found 5 TF-gene connections...
# Working on Hist1h4d...
# 	Found 3 TF-gene connections...
# Working on Hist1h2be...
# 	Found 5 TF-gene connections...
# Working on Hist1h1e...
# 	Found 4 TF-gene connections...
# Working on Hist1h3c...
# 	Found 3 TF-gene connections...
# Working on Hist1h2bb...
# 	Found 5 TF-gene connections...
# Working on Hist1h2ab...
# 	Found 4 TF-gene connections...
# Working on Hist1h3b...
# 	Found 3 TF-gene connections...
# Working on Hist1h4a...
# 	Found 4 TF-gene connections...
# Working on Hist1h3a...
# 	Found 7 TF-gene connections...
# Working on Hist1h1a...
# 	Found 1 TF-gene connections...
# Working on Gmnn...
# 	Found 4 TF-gene connections...
# Working on F13a1...
# 	Found 9 TF-gene connections...
# Working on Ly86...
# 	Found 9 TF-gene connections...
# Working on Txndc5...
# 	Found 4 TF-gene connections...
# Working on Gcnt2...
# 	Found 106 TF-gene connections...
# Working on Dtnbp1...
# 	Found 5 TF-gene connections...
# Working on Dek...
# 	Found 8 TF-gene connections...
# Working on Cltb...
# 	Found 51 TF-gene connections...
# Working on Mxd3...
# 	Found 18 TF-gene connections...
# Working on Lman2...
# 	Found 17 TF-gene connections...
# Working on H2afy...
# 	Found 14 TF-gene connections...
# Working on Tifab...
# 	Found 18 TF-gene connections...
# Working on Zfp367...
# 	Found 5 TF-gene connections...
# Working on Ctsh...
# 	Found 11 TF-gene connections...
# Working on Plscr1...
# 	Found 8 TF-gene connections...
# Working on Paqr9...
# 	Found 9 TF-gene connections...
# Working on Trf...
# 	Found 9 TF-gene connections...
# Working on Gmppb...
# 	Found 18 TF-gene connections...
# Working on 4833445I07Rik...
# 	Found 4 TF-gene connections...
# Working on Arpp21...
# 	Found 0 TF-gene connections...
# Working on Crtap...
# 	Found 3 TF-gene connections...
# Working on Cmtm8...
# 	Found 106 TF-gene connections...
# Working on Gorasp1...
# 	Found 2 TF-gene connections...
# Working on Csrnp1...
# 	Found 108 TF-gene connections...
# Working on Cx3cr1...
# 	Found 16 TF-gene connections...
# Working on Rpsa...
# 	Found 5 TF-gene connections...
# Working on Rpl14...
# 	Found 8 TF-gene connections...
# Working on Kif15...
# 	Found 9 TF-gene connections...
# Working on Lars2...
# 	Found 110 TF-gene connections...
# Working on Ccr2...
# 	Found 13 TF-gene connections...
# Working on Suv39h1...
# 	Found 2 TF-gene connections...
# Working on Slc38a5...
# 	Found 1 TF-gene connections...
# Working on Cfp...
# 	Found 9 TF-gene connections...
# Working on Ube2a...
# 	Found 12 TF-gene connections...
# Working on Rpl39...
# 	Found 31 TF-gene connections...
# Working on C1galt1c1...
# 	Found 6 TF-gene connections...
# Working on Gria3...
# 	Found 6 TF-gene connections...
# Working on Bgn...
# 	Found 109 TF-gene connections...
# Working on Pola1...
# 	Found 2 TF-gene connections...
# Working on Maged1...
# 	Found 89 TF-gene connections...
# Working on F630028O10Rik...
# 	Found 10 TF-gene connections...
# Working on Dlg3...
# 	Found 57 TF-gene connections...
# Working on Ogt...
# 	Found 98 TF-gene connections...
# Working on Tspan6...
# 	Found 8 TF-gene connections...
# Working on Gprasp2...
# 	Found 93 TF-gene connections...
# Working on Prdx4...
# 	Found 14 TF-gene connections...

# %%
conn_results["Clec12a"]["new_conns"]["TF_CON"].value_counts()
# Out:
# Cebpb    516
# Cebpa    503
# Nfil3    477
# Cebpe    434
# Spi1     134
# Irf8      72
# Jdp2      57
# Xbp1      22
# Atf6b      2
# Atf6       2
# Mlx        1
# Usf1       1
# Tfec       1
# Usf2       1
# Name: TF_CON, dtype: int64

# %%
conn_results["Cd55"]["new_conns"]["TF_CON"].value_counts()
# Out:
# Sp3        284
# Sp1        265
# Klf3       228
# Sp4        155
# Maz        150
# Patz1      121
# Klf1       121
# Klf8       114
# Gata2      110
# Gata1      110
# Tal1       110
# Srebf1      64
# Tfe3        64
# Arnt        61
# Mycn        61
# Bhlhe41     61
# Zbtb33      35
# Atf1        27
# Crem        26
# Crebl2      24
# Nfe2        23
# Bach1       23
# Nfe2l2      23
# Pbx3        22
# Gfi1b       22
# Pbx4        22
# Nfyb        22
# Gmeb1       14
# Rfx2         8
# Tbx2         3
# Name: TF_CON, dtype: int64

# %%
conn_results["Cebpe"]["new_conns"]["TF_CON"].value_counts()
# Out:
# Cebpa    353
# Cebpb    347
# Cebpe    314
# Jdp2      59
# Xbp1      28
# Atf6b      7
# Atf6       7
# Spi1       2
# Mlx        1
# Tfec       1
# Name: TF_CON, dtype: int64

# %%
conn_results["Cd55"]["seg_tf2gene"].sort_values(ascending=False)
# Out:
# Gfi1b      0.878581
# Gata1      0.837461
# Tal1       0.827702
# Gata2      0.795273
# Tfe3       0.728333
# Pbx4       0.699658
# Rfx2       0.610257
# Klf1       0.594871
# Nfe2l2     0.576854
# Maz        0.553370
# Sp4        0.516170
# Patz1      0.512400
# Tbx2       0.495987
# Sp1        0.495594
# Klf8       0.495121
# Atf1       0.494811
# Gmeb1      0.491863
# Nfe2       0.481047
# Pbx3       0.467066
# Nfyb       0.465362
# Sp3        0.459121
# Crebl2     0.443504
# Zbtb33     0.430716
# Klf3       0.428576
# Bhlhe41    0.417026
# Srebf1     0.415674
# Mycn       0.408364
# Bach1      0.404901
# Arnt       0.404558
# Crem       0.403207
# Name: Cd55, dtype: float64

# %%
conn_results["Irf8"]["seg_tf2gene"].sort_values(ascending=False)
# Out:
# Irf8      1.000000
# Nfil3     0.808144
# Hes6      0.781232
# Atf6b     0.723927
# Atf6      0.720608
# Hesx1     0.718806
# Usf1      0.679093
# Spi1      0.631385
# Usf2      0.494897
# Cebpa     0.489089
# Tfec      0.466902
# Sp9       0.458169
# Prrxl1    0.440107
# Name: Irf8, dtype: float64

# %%
print("\n".join(conn_results["Irf8"]["seg_tf2gene"].sort_values(ascending=False).index.values))
# Out:
# Irf8
# Nfil3
# Hes6
# Atf6b
# Atf6
# Hesx1
# Usf1
# Spi1
# Usf2
# Cebpa
# Tfec
# Sp9
# Prrxl1

# %%
conn_results.keys()
# Out:
# dict_keys(['Ube2w', 'Crispld1', 'Mcm3', 'Dst', 'Rnf149', 'Il1r1', 'Il1rl1', 'Gm973', 'Idh1', 'Acadl', 'Ikzf2', 'Cxcr2', 'Serpine2', 'Dock10', 'Arl4c', 'Otos', 'Gpc1', 'Zcchc2', 'Bcl2', 'Dbi', 'Cd55', 'Ctse', 'Slc45a3', 'Btg2', 'Ptpn7', 'Aspm', 'Uchl5', 'Rgs2', 'Rgs1', 'Fam129a', 'Edem3', 'Ier5', '4930523C07Rik', 'Prdx6', 'Sell', 'Pbx1', 'Pcp4l1', 'Fcer1g', 'Cd48', 'Slamf1', 'Spta1', 'Fh1', 'Exo1', 'H3f3a', 'Cenpf', 'Ptpn14', 'Dtl', 'Nek2', 'Hsd11b1', 'G0s2', 'Cd34', 'Mical1', 'Cisd1', 'Ggt5', 'Mif', 'Itgb2', 'Prss57', 'Ptbp1', 'Plppr3', 'Ndufs7', 'Rps15', 'Mob3a', 'Lsm7', 'Sppl2b', 'Tle6', 'D10Wsu102e', 'Bpifc', 'Timp3', 'Gnptab', 'Gas2l3', 'Lta4h', 'Gm15915', 'Socs2', 'Dusp6', 'E2f7', 'Osbpl8', 'Nap1l1', 'Phlda1', 'Tspan8', 'Lyz2', 'Rap1b', 'Hmga2', 'Ctdsp2', 'Cdk4', 'Pa2g4', 'Cd63', 'Tespa1', 'Patz1', 'Nefh', 'H2afv', 'Meis1', 'Cep68', 'Snrnp25', 'Btnl9', 'Mgat1', 'Tbc1d9b', 'Ltc4s', 'Uqcrq', 'Gm2a', 'Obscn', 'Shmt1', 'Mmgt2', 'Rpl26', 'Kdm6b', 'Trp53', 'Atp1b2', 'Cd68', 'Nlgn2', 'Mgl2', 'Txndc17', 'Spns2', 'Scarf1', 'Slfn9', '1700020L24Rik', 'Ccl9', 'Ccl3', 'Ccl4', 'Wfdc17', 'Wfdc18', 'Prr11', 'Hlf', 'Lrrc59', 'Fam117a', 'Gngt2', 'Tbkbp1', 'Cisd3', 'Nt5c3b', 'Kif18b', 'Itgb3', 'Icam2', 'Ern1', 'Tex2', 'Pecam1', 'Gm11697', 'Grb2', 'Smim5', 'Sphk1', 'Tk1', 'Mfsd2b', 'Sdc1', 'Mycn', 'Trib2', 'Pdia6', 'Klf11', 'Rrm2', 'Rnf144a', 'Rnaseh1', 'Scin', 'Egln3', 'Mis18bp1', 'Pole2', 'Zbtb25', 'Zbtb1', 'Tmem229b', 'Fos', 'Ifi27', 'Serpina3g', 'Meg3', 'Tnfaip2', 'Ppp1r13b', 'Pld4', 'Crip2', 'Crip1', 'Ighm', 'Klf6', 'Gpr141', 'Zkscan8', 'Hist1h2ai', 'Hist1h2bm', 'Hist1h2ak', 'Hist1h2bn', 'Hist1h1b', 'Hist1h2an', 'Hist1h2ap', 'Hist1h2bj', 'Hist1h4h', 'Hist1h2af', 'Hist1h3f', 'Hist1h1d', 'Hist1h3e', 'Hist1h2ae', 'Hist1h4d', 'Hist1h2be', 'Hist1h1e', 'Hist1h3c', 'Hist1h2bb', 'Hist1h2ab', 'Hist1h3b', 'Hist1h4a', 'Hist1h3a', 'Hist1h1a', 'Gmnn', 'F13a1', 'Ly86', 'Txndc5', 'Gcnt2', 'Dtnbp1', 'Dek', 'Cltb', 'Mxd3', 'Lman2', 'H2afy', 'Tifab', 'Zfp367', 'F2r', 'F2rl2', 'Smn1', 'Cenph', 'Ccnb1', 'Il6st', 'Ddx4', 'Parp8', 'Emb', 'Ube2e2', 'Rps24', 'Ccdc66', 'Chdh', 'Nt5dc2', 'Sh3bp5', 'Cdkn3', 'Rnase12', 'Rnase6', 'Hnrnpc', 'Cebpe', 'Nop9', 'Ltb4r1', 'Mcpt8', 'Pbk', 'Esco2', 'Clu', 'Dpysl2', 'Tsc22d1', 'Rgcc', 'Kctd12', 'Gm10076', 'Clybl', 'Zfp706', 'Azin1', 'Angpt1', 'Rad21', 'Dscc1', 'Sqle', 'Fam49b', 'Ly6a', 'Ly6c2', 'Pycrl', 'Csf2rb', 'Lgals1', 'Gcat', 'Rpl3', 'Tnrc6b', 'Nfam1', 'Prr5', 'Abcd2', 'Hdac7', 'Fkbp11', 'Tuba1b', 'Racgap1', 'Nr4a1', 'Tns2', 'Rmi2', 'Litaf', 'Snn', 'Abcc1', 'Mcm4', '2610318N02Rik', 'Sdf2l1', 'Ranbp1', 'Gp1bb', 'Rtp4', 'Hes1', 'Bex6', 'Tctex1d2', 'Iqcb1', 'Ift57', 'Alcam', 'Nfkbiz', 'Nrip1', 'Gart', 'Itsn1', 'Slc22a3', 'Mrpl18', 'Pkmyt1', 'Prss34', 'Dusp1', 'Phf1', 'Rps10', 'Rpl10a', 'Dnah8', 'Abcg1', 'Rps28', 'Psmb8', 'Tap2', 'Sapcd1', 'Clic1', 'Ddah2', 'Lst1', 'Ltb', 'Cchcr1', 'Tubb5', 'Runx2', 'Hsp90ab1', 'Dnph1', 'Trem3', 'Treml1', 'Satb1', 'Chaf1a', 'Uhrf1', 'C3', 'Fbxl17', 'Vapa', 'Myom1', 'Lpin2', 'Emilin2', 'Ehd3', 'Ltbp1', 'Crim1', 'Bambi', 'Galnt1', 'Bin1', 'Egr1', 'Ctnna1', 'Arap3', 'Tnfaip8', 'Aldh7a1', 'Ndst1', 'Rps14', 'Camk2a', 'Pdgfrb', 'Csf1r', 'Spire1', 'Ldlrad4', 'Rab27b', 'Smad7', 'Slc14a1', 'Zadh2', 'Cndp2', 'Unc93b1', 'Incenp', 'AW112010', 'Ms4a6c', 'Ms4a6b', 'Ms4a2', 'Ms4a3', 'Mpeg1', 'Fam111a', 'Carnmt1', 'Gda', 'Klf9', 'Vldlr', 'Papss2', 'Cep55', 'Hells', 'Dntt', 'Pgam1', 'Nkx2-3', 'Sfxn3', 'Fbxw4', 'Slc18a2', 'Optn', 'Itih5', 'Pfkfb3', 'St8sia6', 'Sapcd2', 'Notch1', 'Egfl7', 'Rpl7a', 'Gfi1b', 'Endog', 'Tor1a', 'Ass1', 'Rpl12', 'Rpl35', 'Arl6ip6', 'Nr4a2', 'Spc25', 'Klhl23', 'Hat1', 'Cdca7', 'Agps', 'Ube2l6', 'Ptprj', 'Fnbp4', 'Cstf3', 'Elp4', 'Knstrn', 'Nusap1', 'Pdia3', 'Hdc', 'Dusp2', 'Itpa', 'Cdc25b', 'Pcna', 'Macrod2', 'Gins1', 'Fkbp1a', 'Tcf15', 'Nol4l', 'Procr', 'Uqcc1', 'Tgm2', 'Slpi', 'Trp53rka', 'Psma7', 'C030034L19Rik', 'Fabp5', 'Car1', 'Cpa3', 'Nceh1', 'Fndc3b', 'Mecom', 'Gnb4', 'Ndufb5', 'Dcun1d1', 'Noct', 'Mgst2', 'Lhfp', 'Tsc22d2', 'Gpr171', 'Il12a', 'Pear1', 'Smg5', 'Lmna', 'Fdps ...

# %%
conn_results["Cd55"]["new_conns"].loc[conn_results["Cd55"]["new_conns"]["TF_CON"] == "Gata1"].sort_values(by="start")
# Out:
#        Gene  seqlet_idx         r     index   chr      start        end  \
# 23521  Cd55    12747852  0.616601  12747852  chr1  130462237  130462267
# 23366  Cd55     9914898  0.646602   9914898  chr1  130508677  130508707
# 23113  Cd55     4965645  0.648227   4965645  chr1  130508678  130508708
# 23175  Cd55     6134095  0.647968   6134095  chr1  130508678  130508708
# 23141  Cd55     5601305  0.646755   5601305  chr1  130508678  130508708
# ...     ...         ...       ...       ...   ...        ...        ...
# 23568  Cd55    12748099  0.737403  12748099  chr1  131074762  131074792
# 23037  Cd55     2834413  0.783729   2834413  chr1  131087544  131087574
# 23365  Cd55     9223717  0.784526   9223717  chr1  131087544  131087574
# 22918  Cd55     1466857  0.785324   1466857  chr1  131087544  131087574
# 23570  Cd55    12748111  0.785634  12748111  chr1  131087544  131087574
#
#                            peak      score  pos strand  \
# 23521  chr1:130462037-130463037   8.967998  201      +
# 23366  chr1:130508232-130509232  10.065369  446      +
# 23113  chr1:130508232-130509232   9.349007  447      +
# 23175  chr1:130508232-130509232   9.272098  447      +
# 23141  chr1:130508232-130509232   8.848876  447      -
# ...                         ...        ...  ...    ...
# 23568  chr1:131074102-131075102   8.566227  661      +
# 23037  chr1:131086598-131087598   7.887138  947      -
# 23365  chr1:131086598-131087598   8.353361  947      +
# 22918  chr1:131086598-131087598   8.147350  947      +
# 23570  chr1:131086598-131087598   8.255949  947      +
#
#                              pattern  in_modisco                  seq_name  \
# 23521      MultiLin_1_MEP__pattern_4       False  chr1:130462237-130462267
# 23366                 MKP__pattern_3        True  chr1:130508677-130508707
# 23113  HSCP_HPC_Hist1h2af__pattern_5       False  chr1:130508678-130508708
# 23175            HSCP_MKP__pattern_3       False  chr1:130508678-130508708
# 23141        HSCP_HPC_Tk1__pattern_8       False  chr1:130508678-130508708
# ...                              ...         ...                       ...
# 23568      MultiLin_1_MEP__pattern_4       False  chr1:131074762-131074792
# 23037                ERP2__pattern_0       False  chr1:131087544-131087574
# 23365                 MEP__pattern_3       False  chr1:131087544-131087574
# 22918                eHSC__pattern_4       False  chr1:131087544-131087574
# 23570      MultiLin_1_MEP__pattern_4       False  chr1:131087544-131087574
#
#        dp_score Cisbp2_TF Cisbp2_TF_Family TF_CON
# 23521  0.292962     Trps1             GATA  Gata1
# 23366  0.602899     Trps1             GATA  Gata1
# 23113  0.225130     Gata1             GATA  Gata1
# 23175  0.355339     Trps1             GATA  Gata1
# 23141  0.408941     Gata1             GATA  Gata1
# ...         ...       ...              ...    ...
# 23568  0.129768     Trps1             GATA  Gata1
# 23037  0.217571     Gata3             GATA  Gata1
# 23365  0.131946      Tal1             bHLH  Gata1
# 22918  0.159680     Gata6             GATA  Gata1
# 23570  0.110537     Trps1             GATA  Gata1
#
# [110 rows x 18 columns]

# %%
# Filter out connections for the same TF within a given distance threshold
cut_distance_threshold = 10
tmp_save_conns = []
for tmp_gene in conn_results:
    if type(conn_results[tmp_gene]["new_conns"]) != type(None):
        for tmp_tf in conn_results[tmp_gene]["new_conns"]["TF_CON"].unique():
            tmp_conns = conn_results[tmp_gene]["new_conns"].copy()
            tmp_conns = tmp_conns.loc[tmp_conns["TF_CON"] == tmp_tf]
            tmp_conns["midpoint"] = tmp_conns[["start", "end"]].mean(axis=1)
            tmp_conns = tmp_conns[["dp_score", "midpoint"]].sort_values(\
                by="dp_score", ascending=False)
            saved_indices = []
            while tmp_conns.shape[0] > 0:
                saved_indices.append(tmp_conns.index.values[0])
                tmp_conns = tmp_conns.loc[\
                    (tmp_conns["midpoint"] - tmp_conns["midpoint"].iloc[0]).abs() > \
                        cut_distance_threshold]

            tmp_save_conns.append(conn_results[tmp_gene]["new_conns"].loc[\
                saved_indices])

# %%
unique_conns = pd.concat(tmp_save_conns)

# %%
(unique_conns["Gene"] + ":" + unique_conns["TF_CON"]).value_counts()
# Out:
# Smim14:Spi1      3956
# Smim14:Etv6      3938
# Smim14:Erg       3861
# Smim14:Ets1      3861
# Smim14:Fli1      3701
#                  ...
# Chd7:Thap11         1
# Cmtm8:Atf4          1
# Cmtm8:Nfe2l1        1
# Tox:Gata6           1
# Rnf122:Zfp212       1
# Length: 21961, dtype: int64

# %%
unique_conns.loc[unique_conns["TF_CON"] == "Cebpe", "Gene"].value_counts().head(50)
# Out:
# Hvcn1            931
# Lta4h            629
# Tor1a            427
# Spcs2            410
# Hk2              292
# Ms4a3            276
# Clec5a           262
# Ern1             251
# Pgam1            250
# Tex2             235
# Cox5a            232
# Mical1           228
# Tyrobp           219
# Fndc3b           214
# Gsr              201
# Sdf2l1           199
# Dmkn             197
# Clec12a          194
# Pdia4            183
# 1700020L24Rik    180
# Adgrg3           177
# Nfam1            169
# Papss2           168
# Slpi             159
# Ube2w            156
# Fdps             149
# Cebpe            148
# Gmppb            147
# Aprt             143
# Pfkfb3           139
# Erp29            138
# Nt5dc2           132
# Mogs             128
# Txndc17          126
# Ift57            125
# Ly6c2            123
# Gda              121
# Mgl2             121
# Fgl2             121
# Trem3            117
# Tmem165          115
# Lman2            106
# Prss57           106
# Igsf6            105
# Fam49b           101
# Pdia6             99
# Pdia3             98
# Abcd2             98
# Mgam              97
# 2610318N02Rik     96
# Name: Gene, dtype: int64

# %%
unique_conns
# Out:
#           Gene  seqlet_idx         r     index   chr      start        end  \
# 215      Ube2w     2459399  0.627987   2459399  chr1   16220342   16220372
# 215      Ube2w     2459399  0.627987   2459399  chr1   16220342   16220372
# 215      Ube2w     2459399  0.627987   2459399  chr1   16220342   16220372
# 215      Ube2w     2459399  0.627987   2459399  chr1   16220342   16220372
# 215      Ube2w     2459399  0.627987   2459399  chr1   16220342   16220372
# ...        ...         ...       ...       ...   ...        ...        ...
# 1365828  Prdx4    13899421  0.498424  13899421  chrX  155195322  155195352
# 1365830  Prdx4    13899472  0.441628  13899472  chrX  155338404  155338434
# 1365785  Prdx4    12017455  0.457291  12017455  chrX  155338451  155338481
# 1365499  Prdx4     3762026  0.541284   3762026  chrX  155338432  155338462
# 1365615  Prdx4     6722346  0.518341   6722346  chrX  155338420  155338450
#
#                              peak     score  pos strand  \
# 215        chr1:16219841-16220841  5.955649  502      -
# 215        chr1:16219841-16220841  5.955649  502      -
# 215        chr1:16219841-16220841  5.955649  502      -
# 215        chr1:16219841-16220841  5.955649  502      -
# 215        chr1:16219841-16220841  5.955649  502      -
# ...                           ...       ...  ...    ...
# 1365828  chrX:155194641-155195641  8.504064  682      +
# 1365830  chrX:155337965-155338965  5.269765  440      +
# 1365785  chrX:155337965-155338965  4.196037  487      -
# 1365499  chrX:155337965-155338965  5.529413  468      +
# 1365615  chrX:155337965-155338965  4.319875  456      -
#
#                               pattern  in_modisco                  seq_name  \
# 215                   ERP1__pattern_5       False    chr1:16220342-16220372
# 215                   ERP1__pattern_5       False    chr1:16220342-16220372
# 215                   ERP1__pattern_5       False    chr1:16220342-16220372
# 215                   ERP1__pattern_5       False    chr1:16220342-16220372
# 215                   ERP1__pattern_5       False    chr1:16220342-16220372
# ...                               ...         ...                       ...
# 1365828  MultiLin_2_F13a1__pattern_15       False  chrX:155195322-155195352
# 1365830  MultiLin_2_F13a1__pattern_15       False  chrX:155338404-155338434
# 1365785          MPP5_Egr1__pattern_3       False  chrX:155338451-155338481
# 1365499               ERP2__pattern_6       False  chrX:155338432-155338462
# 1365615          HSCP_MKP__pattern_22       False  chrX:155338420-155338450
#
#          dp_score Cisbp2_TF Cisbp2_TF_Family TF_CON
# 215      0.300545     Atf6b             bZIP    Mlx
# 215      0.300545     Atf6b             bZIP   Usf1
# 215      0.300545     Atf6b             bZIP  Atf6b
# 215      0.300545     Atf6b             bZIP   Xbp1
# 215      0.300545     Atf6b             bZIP   Atf6
# ...           ...       ...              ...    ...
# 1365828  0.103848      Taf1          Unknown   Taf1
# 1365830  0.081610      Taf1          Unknown   Taf1
# 1365785  0.711442      Nrf1          Unknown   Nrf1
# 1365499  0.136637      Nrf1          Unknown   Nrf1
# 1365615  0.120699      Nrf1          Unknown   Nrf1
#
# [3404668 rows x 18 columns]

# %%
# Read in the dotproduct scores for chrombpnet factors
dpscores = pd.read_feather("output/chrombpnet/modisco_merged_results/fold_0/"\
    "redo_extract_seqlets/all_seqlit_hits_above_modisco_min_dp_scores.fea")
dpscores = dpscores.set_index("index")
dpscores
# Out:
#               BMCP  CD127_MP  CLP1_Rrm2      eHSC  eHSC_Pcna      ERP1  \
# index
# 0         0.318700  0.182511   0.072353 -0.032767   0.016769 -0.010280
# 1         0.309506  0.181138   0.072640 -0.033765   0.004125 -0.009126
# 2         0.153212  0.162171   0.122635  0.164242   0.111058  0.076880
# 3         0.096635  0.089786   0.069505  0.070600   0.069142  0.054534
# 4         0.092790  0.087732   0.059760  0.061709   0.055632  0.050725
# ...            ...       ...        ...       ...        ...       ...
# 16097284  0.226564  0.257879   0.167280  0.189565   0.590309  0.371887
# 16097285  0.211593  0.270772   0.173492  0.190040   0.619284  0.372037
# 16097286  0.157064  0.160043   0.098415  0.402791   0.357010  0.225733
# 16097287  1.418154  1.215912   1.336111  2.568458   2.638613  1.873825
# 16097288  0.747094  1.133173   0.737652  1.239949   1.630026  1.193417
#
#               ERP2  HSCP_ERP1  HSCP_HPC_Cenpf  HSCP_HPC_Hist1h2af  ...  \
# index                                                              ...
# 0        -0.011614  -0.018222       -0.001942            0.103659  ...
# 1        -0.010140  -0.018198       -0.003931            0.091665  ...
# 2         0.040337   0.076493        0.186548            0.236789  ...
# 3         0.084802   0.076695        0.084515            0.077108  ...
# 4         0.081025   0.075760        0.073507            0.070626  ...
# ...            ...        ...             ...                 ...  ...
# 16097284  0.173323   0.296042        0.369818            0.313356  ...
# 16097285  0.177751   0.317392        0.407950            0.333013  ...
# 16097286  0.281937   0.334802        0.853461            0.294814  ...
# 16097287  1.706186   1.909492        3.397888            2.753970  ...
# 16097288  0.680911   0.913275        1.541642            1.571360  ...
#
#           MPP5_Egr1  MPP5_Flt3  MultiLin_1  MultiLin_1_MEP  MultiLin_2_F13a1  \
# index
# 0          0.006640   0.014308    0.193462        0.080617          0.056081
# 1         -0.013929   0.012258    0.192524        0.086213          0.043606
# 2          0.085075   0.124055    0.407299        0.136561          0.053496
# 3          0.083484   0.069578    0.078721        0.056535          0.049417
# 4          0.076456   0.071330    0.076957        0.050349          0.039781
# ...             ...        ...         ...             ...               ...
# 16097284   0.223087   0.374202    0.429426        0.248314          0.296760
# 16097285   0.225168   0.362093    0.412769        0.268819          0.312048
# 16097286   0.455269   0.400698    0.307154        0.291346          0.118884
# 16097287   2.027387   2.788655    1.795369        1.130344          1.609973
# 16097288   1.555339   0.850764    1.268808        0.525849          1.212397
#
#           MultiLin_2_Ms4a3  pre_MultiLin_1  pre_MultiLin_2  proNeu_1    ST_HSC
# index
# 0                 0.215750        0.040248        0.071136  0.142187 -0.013152
# 1                 0.212994        0.037983        0.068489  0.150639 -0.025311
# 2                 0.203368        0.149513        0.106462  0.122166  0.099793
# 3                 0.062896        0.050087        0.068793  0.041139  0.081893
# 4                 0.065570        0.048880        0.066689  0.034787  0.078672
# ...                    ...             ...             ...       ...       ...
# 16097284          0.207561        0.360683        0.287468  0.295474  0.413159
# 16097285          0.206281        0.344867        0.277470  0.297095  0.442239
# 16097286          0.161782        0.435491        0.293549  0.050509  0.512000
# 16097287          1.572978        1.808873        1.640395  0.898614  2.852918
# 16097288          0.948771        1.093799        1.093033  0.627716  2.075172
#
# [16097289 rows x 32 columns]

# %%
dpscores_max = dpscores.max(axis=1)

# %%
gexscores_max = cite_rna.max(axis=1)

# %%
dpscores.columns.values
# Out:
# array(['BMCP', 'CD127_MP', 'CLP1_Rrm2', 'eHSC', 'eHSC_Pcna', 'ERP1',
#        'ERP2', 'HSCP_ERP1', 'HSCP_HPC_Cenpf', 'HSCP_HPC_Hist1h2af',
#        'HSCP_HPC_Tk1', 'HSCP_MKP', 'IG2_MP', 'IG2_proNeu1',
#        'LT_HSC_Mllt3', 'MDP_Cpa3', 'MDP_Irf8', 'MEP', 'MKP',
#        'ML_cell_cycle', 'MPP4_Hlf', 'MPP4_Nkx2_3', 'MPP5_Egr1',
#        'MPP5_Flt3', 'MultiLin_1', 'MultiLin_1_MEP', 'MultiLin_2_F13a1',
#        'MultiLin_2_Ms4a3', 'pre_MultiLin_1', 'pre_MultiLin_2', 'proNeu_1',
#        'ST_HSC'], dtype=object)

# %%
cite_rna.columns.values
# Out:
# array(['ERP4_Bcl2l15', 'MultiLin_2_F13a1', 'ERP2_Arhgdig', 'ERP2',
#        'Ebf1+ proB_Smtnl2', 'proNeu_1_ADT', 'preNeu_Ebf1', 'cMoP_S100a4',
#        'immNeu_1', 'CD127_MP', 'proNeu_2', 'Ebf1+ proB_Uhrf1', 'ERP1',
#        'MDP_Irf8', 'preNeu_3', 'ERP4_Alas2', 'preNeu_3_ADT', 'immNeu_2',
#        'preNeu_1', 'immNeu_3', 'cMoP_Mki67', 'pre_MultiLin_2',
#        'Bcl11b+_preETP_Tdrd5', 'MPP5_Flt3', 'Ebf1+ proB_Mxd3',
#        'IG2_proNeu1', 'cKit_Mast', 'ML_cell_cycle', 'HSCP_HPC_Cenpf',
#        'MultiLin_2_Ms4a3', 'MDP_Cpa3', 'proNeu_1', 'pre_cDC1_Xcr1',
#        'HSCP_HPC_Tk1', 'Pro_B', 'pre_B_Fcer2a', 'CLP1_Hist1h1c',
#        'MultiLin_1_Elane', 'ETP_A_0', 'ETP_CC_4', 'eHSC_Pcna',
#        'MPP4_Ccr9', 'IG2_MP', 'Baso', 'B_cell progenitor', 'HSCP_ERP1',
#        'plasmaDC', 'preNeu_3_Mac_C1qa', 'DN4_DP_trans_Hist1h3c',
#        'MultiLin_1_MEP', 'ILC1_ILC3_NKP', 'pre_cDC1_Egfl8', 'MEP_UNK',
#        'MKP', 'HSCP_MKP', 'pre_cDC2', 'pDC_2', 'MultiLin_1', 'CLP1_Rrm2',
#        'BMCP', 'alphaLP', 'CLP2', 'Eosinophils', 'Bcl11b+_preETP_Cd3d',
#        'MultiLin_1_preBMCP', 'ILCP_Clip4', 'HSC_Mac_Fcna',
#        'HSCP_HPC_Hist1h2af', 'pre_B_Il2ra', 'ML_ERP2_ADT',
#        'ETP_IFN_10_Ifit3', 'Ebf1+ proB_Hmga2', 'ML_Mast', 'Mac_Fn1',
#        'LT_HSC_Mllt3', 'ST_HSC_CC_Mac_1', 'CD127_BMCP', 'ST_HSC',
#        'ILCP_Tox2', 'pDC_1', 'eHSC', 'EILP', 'ILC2', 'CHILP',
#        'pre_MultiLin_1', 'MEP', 'MPP4_Hlf', 'MPP5_Egr1', 'MPP4_Nkx2_3',
#        'ST_HSC_CC_Mac_2'], dtype=object)

# %%
dpscore_threshold = 0.05
gex_threshold = 0.1

cluster_gexscores = {}
cluster_conns = {}
for tmp_cluster in dpscores.columns.values:
    print(f"{tmp_cluster}...")
    tmp_dpscores = dpscores[tmp_cluster].copy()
    tmp_dpscores.loc[tmp_dpscores < dpscore_threshold] = 0
    tmp_dpscores = tmp_dpscores / dpscores_max.loc[tmp_dpscores.index.values].abs()
    tmp_gexscores = cite_rna[tmp_cluster].copy()
    tmp_gexscores.loc[tmp_gexscores < 0.1] = 0
    tmp_gexscores = tmp_gexscores / gexscores_max.loc[tmp_gexscores.index.values]
    tmp_conns = unique_conns.copy()
    tmp_conns = tmp_conns.loc[~tmp_conns["Gene"].str.startswith("Rps")]
    tmp_conns = tmp_conns.loc[~tmp_conns["Gene"].str.startswith("Rpl")]
    tmp_conns["con_score"] = (\
        tmp_dpscores.loc[tmp_conns["seqlet_idx"].values] * \
        tmp_gexscores.loc[tmp_conns["Gene"].values].values * \
        tmp_gexscores.loc[tmp_conns["TF_CON"].values].values).values
    tmp_conns = tmp_conns.loc[tmp_conns["con_score"] > 0]
    cluster_conns[tmp_cluster] = tmp_conns
    cluster_gexscores[tmp_cluster] = tmp_gexscores
# Out:
# BMCP...
# CD127_MP...
# CLP1_Rrm2...
# eHSC...
# eHSC_Pcna...
# ERP1...
# ERP2...
# HSCP_ERP1...
# HSCP_HPC_Cenpf...
# HSCP_HPC_Hist1h2af...
# HSCP_HPC_Tk1...
# HSCP_MKP...
# IG2_MP...
# IG2_proNeu1...
# LT_HSC_Mllt3...
# MDP_Cpa3...
# MDP_Irf8...
# MEP...
# MKP...
# ML_cell_cycle...
# MPP4_Hlf...
# MPP4_Nkx2_3...
# MPP5_Egr1...
# MPP5_Flt3...
# MultiLin_1...
# MultiLin_1_MEP...
# MultiLin_2_F13a1...
# MultiLin_2_Ms4a3...
# pre_MultiLin_1...
# pre_MultiLin_2...
# proNeu_1...
# ST_HSC...

# %%
total_tf_gene_conns = (unique_conns["TF_CON"] + ":" + \
    unique_conns["Gene"]).value_counts()

# %%
tf2gene_conn_counts = pd.DataFrame(0, index=total_tf_gene_conns.index.values, columns=list(cluster_conns.keys()))
for tmp_cluster in cluster_conns:
    tmp_vcounts = (cluster_conns[tmp_cluster]["TF_CON"] + ":" + \
        cluster_conns[tmp_cluster]["Gene"]).value_counts()
    tf2gene_conn_counts.loc[\
        tmp_vcounts.index.values, 
        tmp_cluster] = tmp_vcounts.values


tf2gene_conn_counts
# Out:
#                BMCP  CD127_MP  CLP1_Rrm2  eHSC  eHSC_Pcna  ERP1  ERP2  \
# Spi1:Smim14    3324      3749       3726  3563       3658     0     0
# Etv6:Smim14    3370      3731       3717  3596       3662  1727     0
# Erg:Smim14     3297      3655       3644  3522       3585     0     0
# Ets1:Smim14    3299         0       3646     0          0     0     0
# Fli1:Smim14    3165      3510       3501  3385       3437     0     0
# ...             ...       ...        ...   ...        ...   ...   ...
# Thap11:Chd7       0         1          0     0          0     0     0
# Atf4:Cmtm8        0         0          0     0          1     0     0
# Nfe2l1:Cmtm8      0         0          0     0          1     0     0
# Gata6:Tox         0         0          0     0          0     0     0
# Zfp212:Rnf122     0         0          0     0          1     0     0
#
#                HSCP_ERP1  HSCP_HPC_Cenpf  HSCP_HPC_Hist1h2af  ...  MPP5_Egr1  \
# Spi1:Smim14         1385            3921                3872  ...       3799
# Etv6:Smim14         1453            3915                3887  ...       3786
# Erg:Smim14          1431            3838                3811  ...       3709
# Ets1:Smim14            0            3838                3812  ...       3709
# Fli1:Smim14         1412            3682                3657  ...       3550
# ...                  ...             ...                 ...  ...        ...
# Thap11:Chd7            0               0                   0  ...          0
# Atf4:Cmtm8             0               0                   0  ...          1
# Nfe2l1:Cmtm8           0               0                   0  ...          1
# Gata6:Tox              0               0                   0  ...          0
# Zfp212:Rnf122          0               1                   0  ...          1
#
#                MPP5_Flt3  MultiLin_1  MultiLin_1_MEP  MultiLin_2_F13a1  \
# Spi1:Smim14         3801        3811            3334              3720
# Etv6:Smim14         3803        3821            3375              3714
# Erg:Smim14          3726        3744            3307              3640
# Ets1:Smim14         3725           0               0                 0
# Fli1:Smim14         3566        3591            3193              3514
# ...                  ...         ...             ...               ...
# Thap11:Chd7            0           0               0                 0
# Atf4:Cmtm8             1           0               0                 0
# Nfe2l1:Cmtm8           1           0               0                 0
# Gata6:Tox              0           0               0                 0
# Zfp212:Rnf122          1           0               0                 0
#
#                MultiLin_2_Ms4a3  pre_MultiLin_1  pre_MultiLin_2  proNeu_1  \
# Spi1:Smim14                3823            3797            3685      3554
# Etv6:Smim14                3803            3819            3707      3577
# Erg:Smim14                 3728            3742            3635      3507
# Ets1:Smim14                   0            3742               0      3526
# Fli1:Smim14                3580            3587            3492      3387
# ...                         ...             ...             ...       ...
# Thap11:Chd7                   0               0               0         1
# Atf4:Cmtm8                    0               0               0         0
# Nfe2l1:Cmtm8                  0               0               0         0
# Gata6:Tox                     0               0               0         0
# Zfp212:Rnf122                 0               0               0         0
#
#                ST_HSC
# Spi1:Smim14      3565
# Etv6:Smim14      3556
# Erg:Smim14       3481
# Ets1:Smim14      3481
# Fli1:Smim14      3327
# ...               ...
# Thap11:Chd7         0
# Atf4:Cmtm8          1
# Nfe2l1:Cmtm8        1
# Gata6:Tox           0
# Zfp212:Rnf122       1
#
# [21961 rows x 32 columns]

# %%
total_tf_conns = unique_conns["TF_CON"].value_counts()
tf_conn_counts = pd.DataFrame(0, index=total_tf_conns.index.values, columns=list(cluster_conns.keys()))
for tmp_cluster in cluster_conns:
    tmp_vcounts = cluster_conns[tmp_cluster]["TF_CON"].value_counts()
    tf_conn_counts.loc[\
        tmp_vcounts.index.values, 
        tmp_cluster] = tmp_vcounts.values


tf_conn_counts
# Out:
#         BMCP  CD127_MP  CLP1_Rrm2   eHSC  eHSC_Pcna   ERP1  ERP2  HSCP_ERP1  \
# Etv6   52330     36063      80292  81224     100365  16405  8973      22555
# Erf    47166     30181      75810  77640      97670  14719  9119      20618
# Erg    50337     34443      76894  77895      95710      0     0      21740
# Elf2   43545     26827      68663  71411      88445  13993  8685      19181
# Elk1       0         0          0      0          0      0     0          0
# ...      ...       ...        ...    ...        ...    ...   ...        ...
# Foxd4      0         0          0      0          0      0     0          0
# Elf3       0         0          0      0          0      0     0          0
# Pax2       0         0          0      0          0      0     0          0
# Trps1      1         1          1      0          3      0     0          0
# Irf3       1         1          1      1          1      2     0          2
#
#        HSCP_HPC_Cenpf  HSCP_HPC_Hist1h2af  ...  MPP5_Egr1  MPP5_Flt3  \
# Etv6           101507               86096  ...     106264     107929
# Erf             97815               81704  ...     103756     105009
# Erg             97195               82487  ...     101443     103058
# Elf2            89478               74908  ...      93499      94724
# Elk1                0                   0  ...          0          0
# ...               ...                 ...  ...        ...        ...
# Foxd4               0                   0  ...          0          0
# Elf3                0                   0  ...          0          0
# Pax2                0                   0  ...          0          0
# Trps1               0                   1  ...          2          1
# Irf3                1                   1  ...          1          1
#
#        MultiLin_1  MultiLin_1_MEP  MultiLin_2_F13a1  MultiLin_2_Ms4a3  \
# Etv6        69588           56694             53468             55496
# Erf         64678           51501             48243             50012
# Erg         66554           54616             51189             53056
# Elf2        58823           48766             43480             45505
# Elk1            0               0                 0                 0
# ...           ...             ...               ...               ...
# Foxd4           0               0                 0                 0
# Elf3            0               0                 0                 0
# Pax2            0               0                 0                 0
# Trps1           1               0                 1                 1
# Irf3            1               2                 1                 1
#
#        pre_MultiLin_1  pre_MultiLin_2  proNeu_1  ST_HSC
# Etv6            95343           91495     36105  103163
# Erf             91684           87745         0  101299
# Erg             91166           87597     34770   98490
# Elf2            82897           80116     27529   91087
# Elk1                0               0         0       0
# ...               ...             ...       ...     ...
# Foxd4               0               0         0       0
# Elf3                0               0         0       0
# Pax2                0               0         0       0
# Trps1               3               1         0       0
# Irf3                1               1         1       1
#
# [204 rows x 32 columns]

# %%
log2_tf_conn_counts = np.log2(tf_conn_counts + 1)

# %%
from pyInfinityFlow.InfinityFlow_Utilities import marker_finder

mfr, mfp = marker_finder(\
    log2_tf_conn_counts.T, 
    log2_tf_conn_counts.columns.values)

mfr = mfr.dropna()
tf_conn_markers = pd.DataFrame({\
        "top_cluster": mfr.idxmax(axis=1),
        "top_corr": mfr.max(axis=1)},
    index=mfr.index.values)

tf_conn_markers
# Out:
#            top_cluster  top_corr
# Etv6          MPP4_Hlf  0.195127
# Erf           MPP4_Hlf  0.092043
# Erg           MPP4_Hlf  0.081364
# Elf2          MPP4_Hlf  0.200655
# Elf4          MPP4_Hlf  0.083809
# ...                ...       ...
# Zfp422     MPP4_Nkx2_3  0.191234
# Max               ERP2  0.493332
# Zfp143             MKP  0.300556
# Trps1        eHSC_Pcna  0.315945
# Irf3    MultiLin_1_MEP  0.402424
#
# [147 rows x 2 columns]

# %%
print(tf_conn_markers.sort_values(by="top_corr", ascending=False).to_string())
# Out:
#                 top_cluster  top_corr
# Foxd2          LT_HSC_Mllt3  1.000000
# Crem                    MEP  1.000000
# Etv5              MPP5_Flt3  0.697649
# Arntl              MPP4_Hlf  0.697071
# Maf                MPP4_Hlf  0.563806
# Mitf           LT_HSC_Mllt3  0.560341
# Max                    ERP2  0.493332
# Bhlhe40        LT_HSC_Mllt3  0.477084
# Myc                    ERP1  0.434158
# Maff               MPP4_Hlf  0.423409
# Atf3               MPP4_Hlf  0.421621
# Gata3    HSCP_HPC_Hist1h2af  0.420747
# Tfeb               MPP4_Hlf  0.420530
# Irf3         MultiLin_1_MEP  0.402424
# E2f4                   ERP1  0.389797
# Bach2          LT_HSC_Mllt3  0.384452
# Cebpe              CD127_MP  0.379528
# Six5               MPP4_Hlf  0.378058
# Hes1           LT_HSC_Mllt3  0.377568
# Egr2               MPP4_Hlf  0.352704
# Rfx1            MPP4_Nkx2_3  0.345975
# Taf1         HSCP_HPC_Cenpf  0.322370
# Foxk2              MDP_Irf8  0.321159
# Ctcf     HSCP_HPC_Hist1h2af  0.318081
# Trps1             eHSC_Pcna  0.315945
# Usf2               CD127_MP  0.312640
# Klf1                   ERP1  0.311871
# Nrf1     HSCP_HPC_Hist1h2af  0.304240
# Mlx                CD127_MP  0.301077
# Nfyb                   ERP2  0.300829
# Zfp143                  MKP  0.300556
# Cebpg         ML_cell_cycle  0.285295
# Atf1     HSCP_HPC_Hist1h2af  0.279341
# Irf7               MPP4_Hlf  0.277793
# Klf11              MPP4_Hlf  0.277182
# Irf5               MPP4_Hlf  0.274717
# Crebl2             MPP4_Hlf  0.274068
# Thap1                ST_HSC  0.273445
# Atf6b              CD127_MP  0.261129
# Yy1          HSCP_HPC_Cenpf  0.257873
# Hes6               CD127_MP  0.256008
# Atf6               CD127_MP  0.255855
# Xbp1               CD127_MP  0.253808
# Atf4           LT_HSC_Mllt3  0.252534
# Junb               MPP4_Hlf  0.249704
# Gata1                  ERP1  0.248090
# Bach1              MPP4_Hlf  0.247926
# Nfyc               MDP_Irf8  0.247677
# Jun                MPP4_Hlf  0.247527
# Jund               MPP4_Hlf  0.246775
# Nfe2               MPP4_Hlf  0.246008
# Atf7               MPP4_Hlf  0.243961
# Rfx3               MPP4_Hlf  0.243253
# Irf9               MPP4_Hlf  0.243019
# Irf8       MultiLin_2_F13a1  0.242439
# Fosl2              MPP4_Hlf  0.240511
# Rest               MPP4_Hlf  0.240175
# Stat1              MPP4_Hlf  0.238060
# Srebf2         LT_HSC_Mllt3  0.237596
# Mnt            LT_HSC_Mllt3  0.237348
# Irf2               MPP4_Hlf  0.237086
# Runx3    HSCP_HPC_Hist1h2af  0.236540
# Atf2               MPP4_Hlf  0.235184
# Sp1                MPP4_Hlf  0.233378
# Creb1              MPP4_Hlf  0.232597
# Thap11             CD127_MP  0.231517
# Usf1               CD127_MP  0.230686
# Mafg           LT_HSC_Mllt3  0.227191
# Gmeb2    HSCP_HPC_Hist1h2af  0.226416
# Zfp281             MPP4_Hlf  0.223288
# Srebf1         LT_HSC_Mllt3  0.222450
# Ddit3              MPP4_Hlf  0.221951
# Rfx7               MPP4_Hlf  0.221655
# Pbx3              MPP5_Egr1  0.221060
# Maz            HSCP_HPC_Tk1  0.218699
# Clock          LT_HSC_Mllt3  0.217847
# Patz1          LT_HSC_Mllt3  0.216405
# Nfya               MPP4_Hlf  0.216371
# Nfix               MPP4_Hlf  0.215682
# Tal1              HSCP_ERP1  0.214718
# Ets1               MPP4_Hlf  0.213220
# Sp2      HSCP_HPC_Hist1h2af  0.210657
# Sp3                MPP4_Hlf  0.209906
# Nfe2l1             MPP4_Hlf  0.208075
# Bcl11a             MPP4_Hlf  0.201844
# Elk4               MPP4_Hlf  0.201704
# Elf2               MPP4_Hlf  0.200655
# Gata2             HSCP_ERP1  0.199515
# Ets2               MPP4_Hlf  0.198365
# Cebpa              CD127_MP  0.197133
# Nfic               MPP4_Hlf  0.195940
# Etv6               MPP4_Hlf  0.195127
# Gabpa        HSCP_HPC_Cenpf  0.193713
# Zfp422          MPP4_Nkx2_3  0.191234
# Gmeb1        HSCP_HPC_Cenpf  0.190021
# Lyl1               MPP4_Hlf  0.189428
# Dbp                MPP4_Hlf  0.184363
# Tef               MPP5_Flt3  0.182827
# Nfia               MPP4_Hlf  0.176248
# Mycn           LT_HSC_Mllt3  0.172422
# Stat2              MPP4_Hlf  0.171996
# Elf1         HSCP_HPC_Cenpf  0.168078
# Tfec               CD127_MP  0.167043
# Pbx4                   ERP2  0.162711
# Jdp2               CD127_MP  0.159336
# Nfe2l2         LT_HSC_Mllt3  0.153670
# Hlf                MPP4_Hlf  0.153339
# Klf4               MPP4_Hlf  0.152594
# Runx1        HSCP_HPC_Cenpf  0.151932
# Cebpb              CD127_MP  0.149908
# Gfi1b    HSCP_HPC_Hist1h2af  0.148923
# Zfp212             MPP4_Hlf  0.147360
# Sp4                MPP4_Hlf  0.141629
# Creb3l2        LT_HSC_Mllt3  0.138086
# Klf7     HSCP_HPC_Hist1h2af  0.135205
# Klf2               MPP4_Hlf  0.134377
# Mxd1               MPP4_Hlf  0.133559
# Mxi1                 ST_HSC  0.132115
# Rfx5               MPP4_Hlf  0.130282
# Mafk               MPP4_Hlf  0.129590
# Fosb               MPP4_Hlf  0.128546
# E2f1              eHSC_Pcna  0.127604
# Irf1               MPP4_Hlf  0.122750
# Klf3               MPP4_Hlf  0.119873
# Arnt           LT_HSC_Mllt3  0.116429
# Fos                MPP4_Hlf  0.116167
# Egr1               MPP4_Hlf  0.116037
# Mbtps2             MPP4_Hlf  0.115661
# Mlxip              MPP4_Hlf  0.112943
# Batf               MPP4_Hlf  0.110809
# Zfp523             MPP4_Hlf  0.107319
# Zbtb17             MPP4_Hlf  0.105544
# Klf10              MPP4_Hlf  0.105202
# Zbtb33             MPP4_Hlf  0.103110
# Klf6               MPP4_Hlf  0.102808
# Zbtb14             MPP4_Hlf  0.100484
# Tfe3         MultiLin_1_MEP  0.098907
# Etv3               MPP4_Hlf  0.093468
# Erf                MPP4_Hlf  0.092043
# Runx2              MPP4_Hlf  0.084953
# Elf4               MPP4_Hlf  0.083809
# Elk3               MPP4_Hlf  0.082051
# Erg                MPP4_Hlf  0.081364
# Fli1         HSCP_HPC_Cenpf  0.072685
# E2f3              eHSC_Pcna  0.072529
# Cbfb     HSCP_HPC_Hist1h2af  0.070838
# Spi1               MDP_Irf8  0.064371

# %%
print(tf_conn_counts.var(axis=1).sort_values(ascending=False).to_string())
# Out:
# Ets1       1.583540e+09
# Erf        1.224591e+09
# Erg        9.378807e+08
# Etv6       9.305325e+08
# Elf2       7.751248e+08
# Klf2       7.561066e+08
# Elf4       7.023678e+08
# Ets2       6.844390e+08
# Etv3       6.439800e+08
# Elk4       6.297425e+08
# Elk3       5.830859e+08
# Sp4        5.825011e+08
# Sp1        5.083561e+08
# Zbtb17     4.669724e+08
# Etv5       3.078177e+08
# Klf11      3.076364e+08
# Sp3        3.063435e+08
# Bcl11a     2.932696e+08
# Klf4       2.872646e+08
# Klf6       2.710303e+08
# Egr1       2.296081e+08
# Elf1       1.940645e+08
# Klf10      1.922203e+08
# Fli1       1.536520e+08
# Zfp281     1.070684e+08
# Patz1      7.673837e+07
# Cebpa      7.112431e+07
# Fosl2      6.310317e+07
# Atf3       6.303789e+07
# Jun        4.245257e+07
# Jund       3.844603e+07
# Junb       3.679532e+07
# Stat2      2.888025e+07
# Irf7       2.873331e+07
# Klf3       2.860153e+07
# Irf1       2.418629e+07
# Max        1.391895e+02
# Myc        1.219506e+02
# Trps1      9.637097e-01
# Irf3       1.250000e-01
# Prdm6      0.000000e+00
# Rfx2       0.000000e+00
# Klf5       0.000000e+00
# Hey2       0.000000e+00
# Irf4       0.000000e+00
# Klf12      0.000000e+00
# Klf8       0.000000e+00
# Tal2       0.000000e+00
# Tcfl5      0.000000e+00
# Etv2       0.000000e+00
# Sp6        0.000000e+00
# Figla      0.000000e+00
# Sp9        0.000000e+00
# Hes2       0.000000e+00
# Spic       0.000000e+00
# Spdef      0.000000e+00
# Etv1       0.000000e+00
# Bcl11b     0.000000e+00
# Elf5       0.000000e+00
# Foxe1      0.000000e+00
# Ctcfl      0.000000e+00
# Gata6      0.000000e+00
# Hes7       0.000000e+00
# Foxd4      0.000000e+00
# Elf3       0.000000e+00
# Pax2       0.000000e+00
# Elk1       0.000000e+00
# Heyl       0.000000e+00
# Ehf        0.000000e+00
# Spib       0.000000e+00
# Creb3l1    0.000000e+00
# Gm28047    0.000000e+00
# Mlxipl     0.000000e+00
# Sp8        0.000000e+00
# Zfp454     0.000000e+00
# Klf15      0.000000e+00
# Hesx1      0.000000e+00
# Zfp661     0.000000e+00
# Tbx2       0.000000e+00
# Etv4       0.000000e+00
# Prrxl1     0.000000e+00
# Zfp287     0.000000e+00
# Hes5       0.000000e+00
# Hey1       0.000000e+00
# Npas2      0.000000e+00
# Rfx8       0.000000e+00
# Creb5      0.000000e+00
# Epas1      0.000000e+00
# Nfib       0.000000e+00
# Bhlhe41    0.000000e+00
# Prdm1      0.000000e+00
# Fev        0.000000e+00
# Nfil3      0.000000e+00
# Wt1        0.000000e+00
# Fosl1      0.000000e+00
# Egr4       0.000000e+00
# Mafb       0.000000e+00

# %%
tf_conn_counts.loc["Cebpe"].sort_values()
# Out:
# BMCP                      0
# pre_MultiLin_2            0
# pre_MultiLin_1            0
# MultiLin_2_Ms4a3          0
# MultiLin_2_F13a1          0
# MultiLin_1_MEP            0
# MultiLin_1                0
# MPP5_Flt3                 0
# MPP5_Egr1                 0
# MPP4_Nkx2_3               0
# MPP4_Hlf                  0
# MKP                       0
# MEP                       0
# MDP_Irf8                  0
# ST_HSC                    0
# HSCP_ERP1                 0
# CLP1_Rrm2                 0
# eHSC                      0
# HSCP_MKP                  0
# HSCP_HPC_Tk1              0
# HSCP_HPC_Hist1h2af        0
# HSCP_HPC_Cenpf            0
# LT_HSC_Mllt3              0
# ERP2                      0
# ERP1                      0
# eHSC_Pcna                 0
# ML_cell_cycle          8556
# MDP_Cpa3               9930
# IG2_MP                10589
# proNeu_1              11607
# IG2_proNeu1           11846
# CD127_MP              11974
# Name: Cebpe, dtype: int64

# %%
print(total_tf_conns.to_string())
# Out:
# Etv6       114263
# Erf        111619
# Erg        109298
# Elf2       100649
# Elk1        97861
# Elf4        97535
# Ets1        96568
# Elk4        91283
# Elf5        88823
# Sp1         87227
# Elk3        86297
# Klf2        83961
# Etv1        82474
# Spic        81652
# Etv3        81605
# Etv5        76856
# Zbtb17      74830
# Sp4         73277
# Sp6         71695
# Sp3         65805
# Klf6        62213
# Ets2        61650
# Bcl11a      58391
# Elf1        57991
# Egr1        53901
# Klf10       53256
# Klf4        52914
# Klf8        52386
# Klf11       52243
# Klf12       47442
# Fli1        45078
# Irf4        44423
# Zfp281      37661
# Patz1       34443
# Jun         25357
# Klf5        25158
# Atf3        24354
# Egr4        24174
# Jund        23787
# Fosl1       23072
# Junb        23033
# Fosl2       23003
# Cebpa       22321
# Wt1         21668
# Klf3        20289
# Nfil3       18499
# Fev         17694
# Gabpa       16784
# Irf2        16625
# Irf1        16191
# Stat1       15742
# Egr2        15728
# Stat2       15679
# Irf7        14654
# Spi1        14546
# Bach2       14526
# Fos         14478
# Fosb        14456
# Prdm1       14390
# Bach1       14317
# Nfe2        14211
# Mafk        14198
# Irf9        14168
# Maf         13807
# Cebpb       13513
# Maff        13303
# Cebpe       12388
# Creb1       11623
# Atf7        10903
# Crebl2      10604
# Batf        10564
# Klf7        10235
# Atf2        10126
# Creb5       10106
# Bhlhe40      7732
# Rfx3         7304
# Rfx8         7207
# Mnt          7048
# Srebf2       7018
# Mycn         6923
# Arnt         6911
# Clock        6874
# Rfx5         6805
# Mxd1         6791
# Tfeb         6779
# Gata1        6706
# Npas2        6671
# Mitf         6665
# Hey1         6511
# Hes5         6456
# Mlxip        6177
# Hes1         6006
# Runx2        5996
# Creb3l2      5229
# Arntl        5122
# Rfx7         5111
# Jdp2         4803
# Runx1        4259
# Klf1         4210
# Lyl1         4203
# Irf8         4132
# Mafg         3756
# Mafb         3529
# Tal1         3434
# Gata2        3373
# Zbtb14       3256
# Xbp1         3209
# E2f4         2987
# Nfix         2845
# Gmeb1        2773
# Mbtps2       2663
# Cbfb         2559
# Srebf1       2549
# Zfp287       2446
# Rfx1         2314
# Runx3        2173
# Atf6b        2103
# Atf6         2027
# Sp2          2002
# Etv4         1907
# Zbtb33       1657
# Gmeb2        1555
# Zfp523       1472
# Zfp661       1469
# Tfe3         1454
# Klf15        1433
# Nrf1         1420
# Taf1         1316
# Zfp454       1215
# Sp8          1149
# Spib         1104
# E2f1         1053
# Nfya          955
# Prdm6         925
# Maz           870
# Usf2          865
# Usf1          793
# Atf1          781
# Irf5          743
# Hlf           724
# Foxd2         693
# Zfp212        684
# Gfi1b         678
# Pbx3          666
# Crem          614
# Dbp           611
# Nfic          574
# Atf4          571
# Tfec          534
# Gm28047       503
# Mlxipl        477
# Tef           460
# Foxk2         460
# Mlx           459
# Hesx1         456
# Hes6          437
# Tbx2          420
# Thap1         411
# Prrxl1        411
# Rest          393
# Yy1           346
# Nfyc          333
# Nfia          332
# Nfyb          322
# Pbx4          275
# Epas1         264
# Nfib          257
# Bhlhe41       252
# Six5          249
# Nfe2l2        245
# Ddit3         238
# Ctcf          224
# Nfe2l1        221
# E2f3          200
# Creb3l1       171
# Ehf           165
# Rfx2          156
# Heyl          146
# Myc           137
# Hey2          125
# Cebpg         107
# Gata3          93
# Thap11         86
# Tal2           78
# Tcfl5          74
# Etv2           71
# Mxi1           70
# Figla          63
# Sp9            59
# Hes2           59
# Zfp422         58
# Spdef          58
# Max            53
# Bcl11b         51
# Zfp143         47
# Foxe1          23
# Ctcfl          23
# Gata6          19
# Hes7           17
# Foxd4          17
# Elf3           10
# Pax2            6
# Trps1           3
# Irf3            2

# %%
unique_conns.loc[unique_conns["TF_CON"] == "Cebpe", "Gene"].value_counts()
# Out:
# Hvcn1      931
# Lta4h      629
# Tor1a      427
# Spcs2      410
# Hk2        292
#           ...
# Capza1      10
# G0s2        10
# Prom1        5
# Noct         2
# Pglyrp1      1
# Name: Gene, Length: 107, dtype: int64

# %%
unique_conns["Gene"].value_counts()
# Out:
# Nlgn2     79629
# Apobr     78979
# Abcg1     71234
# Ndst1     67344
# Socs2     64247
#           ...
# Tespa1        1
# Ifi27         1
# Cdkn3         1
# Cstf3         1
# Mcm3          1
# Name: Gene, Length: 724, dtype: int64

# %%
cluster_conns["BMCP"].keys()
# Out:
# Index(['Gene', 'seqlet_idx', 'r', 'index', 'chr', 'start', 'end', 'peak',
#        'score', 'pos', 'strand', 'pattern', 'in_modisco', 'seq_name',
#        'dp_score', 'Cisbp2_TF', 'Cisbp2_TF_Family', 'TF_CON', 'con_score'],
#       dtype='object')

# %%
pd.DataFrame(cluster_gexscores).to_csv("output/GRN/cluster_gex_scores.csv",
    header=True, index=True, index_label="UID")

# %%
for tmp_cluster in cluster_conns:
    cluster_conns[tmp_cluster].reset_index(drop=True).to_feather(\
        f"output/GRN/cluster_grn_connections/{tmp_cluster}_connections.fea")

# %%
unique_conns.reset_index(drop=True).to_feather(\
    "output/GRN/all_unique_connections.fea")

# %%
unique_conns.loc[unique_conns["Gene"] == "Cpa3"]
# Out:
#         Gene  seqlet_idx         r     index   chr     start       end  \
# 708170  Cpa3    12619184  0.405944  12619184  chr3  19320115  19320145
# 708177  Cpa3    12619317  0.539525  12619317  chr3  19998516  19998546
# 708223  Cpa3    14128525  0.514315  14128525  chr3  19143483  19143513
# 707873  Cpa3      984502  0.408167    984502  chr3  19143621  19143651
# 707877  Cpa3      984558  0.438608    984558  chr3  19406529  19406559
# 708117  Cpa3    10396097  0.405631  10396097  chr3  19438244  19438274
# 707851  Cpa3      437501  0.497000    437501  chr3  20017741  20017771
# 708225  Cpa3    14128556  0.466855  14128556  chr3  19260829  19260859
# 708120  Cpa3    10396117  0.528565  10396117  chr3  19534765  19534795
# 707870  Cpa3      437640  0.629785    437640  chr3  20273089  20273119
# 708122  Cpa3    10396123  0.499743  10396123  chr3  19559334  19559364
# 707867  Cpa3      437627  0.529948    437627  chr3  20222642  20222672
# 707853  Cpa3      437529  0.501987    437529  chr3  20129370  20129400
# 708173  Cpa3    12619219  0.416588  12619219  chr3  19448039  19448069
# 708119  Cpa3    10396115  0.550920  10396115  chr3  19517046  19517076
# 707843  Cpa3      437270  0.427518    437270  chr3  19320131  19320161
# 708244  Cpa3    14592484  0.540095  14592484  chr3  20064899  20064929
# 708085  Cpa3     9029350  0.547787   9029350  chr3  20134292  20134322
# 707870                 BMCP__pattern_9       False  chr3:20273089-20273119
# 708122        ML_cell_cycle__pattern_2       False  chr3:19559334-19559364
# 707867                 BMCP__pattern_9       False  chr3:20222642-20222672
# 707853                 BMCP__pattern_3       False  chr3:20129370-20129400
# 708173           MultiLin_1__pattern_2       False  chr3:19448039-19448069
# 708119        ML_cell_cycle__pattern_2       False  chr3:19517046-19517076
# 707843                 BMCP__pattern_9       False  chr3:19320131-19320161
# 708244       pre_MultiLin_1__pattern_3       False  chr3:20064899-20064929
# 708085             MDP_Irf8__pattern_1       False  chr3:20134292-20134322
# 708169          MultiLin_1__pattern_20       False  chr3:19260833-19260863
# 708200       MultiLin_1_MEP__pattern_6       False  chr3:20155085-20155115
# 708189          MultiLin_1__pattern_20       False  chr3:20223507-20223537
# 708192          MultiLin_1__pattern_20       False  chr3:20273085-20273115
# 708187           MultiLin_1__pattern_7       False  chr3:20223491-20223521
# 707959  HSCP_HPC_Hist1h2af__pattern_22       False  chr3:20130571-20130601
# 708023         IG2_proNeu1__pattern_20       False  chr3:19534768-19534798
# 708265      pre_MultiLin_2__pattern_16       False  chr3:20130922-20130952
# 707957   HSCP_HPC_Hist1h2af__pattern_7       False  chr3:19559249-19559279
# 707849                 BMCP__pattern_5       False  chr3:19693707-19693737
# 708086             MDP_Irf8__pattern_9       False  chr3:20134295-20134325
# 708111        ML_cell_cycle__pattern_4       False  chr3:19143997-19144027
#
#         dp_score Cisbp2_TF Cisbp2_TF_Family TF_CON
# 708170  0.702543     Cebpa             bZIP  Cebpa
# 708177  0.501420     Cebpa             bZIP  Cebpa
# 708223  0.496359     Cebpa             bZIP  Cebpa
# 707873  0.488866     Cebpb             bZIP  Cebpa
# 707877  0.429369     Cebpb             bZIP  Cebpa
# 708117  0.418826     Cebpa             bZIP  Cebpa
# 707851  0.400711     Cebpa             bZIP  Cebpa
# 708225  0.382224      Atf4             bZIP  Cebpa
# 708120  0.334548     Cebpa             bZIP  Cebpa
# 707870  0.274468      Atf4             bZIP  Cebpa
# 708122  0.240523     Cebpa             bZIP  Cebpa
# 707867  0.239819      Atf4             bZIP  Cebpa
# 707853  0.222098     Cebpa             bZIP  Cebpa
# 708173  0.194930     Cebpa             bZIP  Cebpa
# 708119  0.192853     Cebpa             bZIP  Cebpa
# 707843  0.161958      Atf4             bZIP  Cebpa
# 708244  0.139038     Cebpb             bZIP  Cebpa
# 708085  0.119792     Cebpa             bZIP  Cebpa
# 708169  0.435900      Atf2             bZIP   Crem
# 708200  0.390645      Jdp2             bZIP   Crem
# 708189  0.378402      Atf2             bZIP   Crem
# 708192  0.246516      Atf2             bZIP   Crem
# 708187  0.232572     Creb1             bZIP   Crem
# 707959  0.211001      Atf2             bZIP   Crem
# 708023  0.207852      Atf2             bZIP   Crem
# 708265  0.192836      Atf2             bZIP   Crem
# 707957  0.155644     Creb1             bZIP   Crem
# 707849  0.153167      Jdp2             bZIP   Crem
# 708086  0.113051     Creb1             bZIP   Crem
# 708111  0.227351     Runx1             Runt  Runx1
